# %%
import matplotlib.pyplot as plt
import numpy as np
# from train_plot import CostPlot

mmd = np.loadtxt('outputs/Output_MMD_2q-qvm_Gaussiankernel_2000kernel_samples_2000Born_Samples2000Data_samples_500Batch_size_1000Epochs_0.001LR_Exact_Run2/loss/MMD/train')
tv = np.loadtxt('outputs/Output_MMD_2q-qvm_Gaussiankernel_2000kernel_samples_2000Born_Samples2000Data_samples_500Batch_size_1000Epochs_0.001LR_Exact_Run2/loss/TV')

born_prob = []
exact_prob = []
# born_prob = np.loadtxt('outputs/Output_MMD_2q-qvm_Gaussiankernel_2000kernel_samples_2000Born_Samples2000Data_samples_500Batch_size_2500Epochs_0.000LR_Exact_Run2/probs/born/epoch2498')
# exact_prob = np.loadtxt('outputs/Output_MMD_2q-qvm_Gaussiankernel_2000kernel_samples_2000Born_Samples2000Data_samples_500Batch_size_2500Epochs_0.000LR_Exact_Run2/probs/data/epoch2498')

plt.figure(1)
plt.plot(mmd)
plt.plot(tv)
plt.xlabel("Epochs")
plt.ylabel("MMD, TV")
plt.savefig('temp/loss_1000e.png')

# CostPlot(2, 'Gaussian', data_train_test, 2000, 'MMD', mmd, circuit_params, born_probs_list, empirical_probs_list)


# print(born_prob, exact_prob)

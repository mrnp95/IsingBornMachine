# %%
## @package run_and_compare
# This is the main module for this project.
#
# More details.

import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, style
from param_init import NetworkParams
from file_operations_out import PrintFinalParamsToFile, PrintDataToFiles, MakeDirectory, PrintFinalParamsToFile
from file_operations_in import DataImport, DataDictFromFile
from train_plot import CostPlot
from cost_function_train import TrainBorn

from random import shuffle
from auxiliary_functions import TrainTestPartition, num_bytes_needed
from pyquil.api import get_qc
import sys
import os
import time
## This function gathers inputs from file
#
# @param[in] file_name name of file to gather inputs from
# 
# @param[out] N_epochs number of epochs
# @param[out] data_type
# @param[out] N_data_samples
# @param[out] N_born_samples
# @param[out] N_kernel_samples
# @param[out] batch_size
# @param[out] kernel_type
# @param[out] cost_func
# @param[out] device_name
# @param[out] as_qvm_value
#
# @returns listed parameters
def get_inputs(file_name):
    
    with open(file_name, 'r') as input_file:
   
        input_values = input_file.readlines()

        N_epochs = int(input_values[0])
        learning_rate = float(input_values[1])
        data_type = str(input_values[2])
        data_type = data_type[0:len(data_type) - 1]
        N_data_samples = int(input_values[3])
        N_born_samples = int(input_values[4])
        N_kernel_samples = int(input_values[5])
        batch_size = int(input_values[6])
        kernel_type = str(input_values[7])
        kernel_type = kernel_type[0:len(kernel_type) - 1]
        cost_func = str(input_values[8])
        cost_func = cost_func[0:len(cost_func) - 1]
        device_name = str(input_values[9])
        device_name = device_name[0:len(device_name) - 1]

        if int(input_values[10]) == 1:
            as_qvm_value = True
        else:
            as_qvm_value = False

        score = str(input_values[11])
        score = score[0:len(score) - 1]

        stein_eigvecs = int(input_values[12])
        stein_eta = float(input_values[13])

        stein_params = {}
        stein_params[0] = score                 #Choice of method to approximate Stein Score:                   score
        stein_params[1] = stein_eigvecs         #Number of Nystrom Eigenvectors, J for spectral_stein method:   J
        stein_params[2] = stein_eta             #regularization paramter for identity_stein method:             \chi
        stein_params[3] = kernel_type           #Kernel for computing Stein Score, set to be the same as kernel used in Stein Discrpancy                              
   
        '''Number of samples:'''
        N_samples =     [N_data_samples,\
                        N_born_samples,\
                        batch_size,\
                        N_kernel_samples]
        sinkhorn_eps = float(input_values[14])
        run = int(input_values[15])

    return N_epochs, learning_rate, data_type, N_samples, kernel_type, cost_func, device_name, as_qvm_value, stein_params, sinkhorn_eps, run

def SaveAnimation(framespersec, fig, N_epochs, N_qubits, N_born_samples, cost_func, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples):
      
        Writer = animation.writers['ffmpeg']

        writer = Writer(fps=framespersec, metadata=dict(artist='Me'), bitrate=-1)
        
        ani = animation.FuncAnimation(fig, animate, frames=len(born_probs_list), fargs=(N_qubits, N_born_samples, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples), interval = 10)
        
        animations_path = './animations/'
        MakeDirectory(animations_path)
        
        ani.save("animations/%s_%iQbs_%s_Kernel_%iSamples_%iEpochs.mp4" \
                %(cost_func[0:1], N_qubits, kernel_type[0][0], N_born_samples, N_epochs))

        plt.show(block=False)       
        plt.pause(1)
        plt.close()
def PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict):
   
        plt.legend(prop={'size': 7}, loc='best').draggable()
        
        plots_path = './plots/'
        MakeDirectory(plots_path)
        plt.savefig("plots/%s_%iQbs_%s_%iBSamps_%iEpoch.pdf" \
                %(cost_func[0], N_qubits, kernel_type[0][0], N_born_samples, N_epochs))
        
        fig, axs = plt.subplots()
        
        axs.set_xlabel("Outcomes")
        axs.set_ylabel("Probability")
        axs.legend(('Born Probs','Data Probs'))
        axs.set_xticks(range(len(data_exact_dict)))
        axs.set_xticklabels(list(data_exact_dict.keys()),rotation=70)
        axs.set_title("%i Qubits, %s Kernel, %i Born Samples" \
                %(N_qubits, kernel_type[0][0], N_born_samples))
        
        plt.tight_layout()
        
        return fig, axs

def animate(i, N_qubits, N_born_samples, kernel_type,  data_exact_dict, born_probs_list, axs, N_data_samples):
        plot_colour = ['r', 'b']
        axs.clear()
        x = np.arange(len(data_exact_dict))
        axs.bar(x, born_probs_list[i].values(), width=0.2, color= plot_colour[0], align='center')
        axs.bar(x-0.2, data_exact_dict.values(), width=0.2, color='b', align='center')
        axs.set_title("%i Qbs, %s Kernel, %i Data Samps, %i Born Samps" \
                %(N_qubits, kernel_type[0][0], N_data_samples, N_born_samples))
        axs.set_xlabel("Outcomes")
        axs.set_ylabel("Probability")
        axs.legend(('Born Probs','Data Probs'))
        axs.set_xticks(range(len(data_exact_dict)))
        axs.set_xticklabels(list(data_exact_dict.keys()),rotation=70)
      
def bytes_to_int(bytes_list):
    total = 0
    for byte in bytes_list:
        total *= 256
        total += byte

    return total

def read_ints_from_file(N_qubits, N_data_samples, f):
    int_list = [0] * N_data_samples
    bytes_list = list(f.read())
    for sample in range(N_data_samples):
        int_list[sample] = bytes_to_int(bytes_list[sample * num_bytes_needed(N_qubits):(sample + 1) * num_bytes_needed(N_qubits)])

    return int_list


# ## This is the main function
# def main():

#     if len(sys.argv) != 2:
#         sys.exit("[ERROR] : There should be exactly one input. Namely, a txt file containing the input values. Please see the README.md file for more details.")
#     else:
#         N_epochs, learning_rate, data_type, N_samples, kernel_type,cost_func, device_name, as_qvm_value, stein_params, sinkhorn_eps, run = get_inputs(sys.argv[1])
        
#         if type(device_name) is not str:
#                 raise ValueError('The device name must be a string')
#         if (as_qvm_value is not True and as_qvm_value is not False):
#                 raise ValueError('\'as_qvm_value\' must be an integer, either 0, or 1')

#         qc = get_qc(device_name, as_qvm = as_qvm_value)  
#         N_qubits = len(qc.qubits())
#         data_circuit_choice = 'IQP'

#         N_data_samples = N_samples[0]
#         N_born_samples = N_samples[1]

#         if data_type == 'Quantum_Data':

#             try:
#                 data_samples= list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))
#             except:
#                 PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
#                 data_samples = list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))

#         elif data_type == 'Bernoulli_Data':
            
#             try:
#                 with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
#                     data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

#             except:
#                 PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
#                 with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
#                     data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

#             print("read data =")
#             data_samples_orig
#             data_samples = np.zeros((N_data_samples, N_qubits), dtype = int)

#             for sample in range(0, N_data_samples):
            
#                 temp = data_samples_orig[sample]

#                 for outcome in range(0, N_qubits):

#                     data_samples[sample, N_qubits - 1 - outcome] = temp % 2
#                     temp >>= 1

#         else:
#             sys.exit("[ERROR] : data_type should be either 'Quantum_Data' or 'Bernoulli_Data'")
    
#         np.random.shuffle(data_samples)

#         #Split data into training/test sets
#         data_train_test = TrainTestPartition(data_samples)

#         random_seed = 0

#         #Parameters, J, b for epoch 0 at random, gamma = constant = pi/4
#         #Set random seed to 0 to initialise the actual Born machine to be trained
#         initial_params = NetworkParams(qc, random_seed)

#         data_exact_dict = DataDictFromFile(data_type, N_qubits, 'infinite', data_circuit_choice)
#         t0 = time.time()
#         loss, circuit_params, born_probs_list, empirical_probs_list = TrainBorn(qc, cost_func, initial_params, \
#                                                                             N_epochs, N_samples, data_train_test, data_exact_dict, \
#                                                                             kernel_type, 'Precompute', learning_rate, \
#                                                                             stein_params, sinkhorn_eps)


#         t1 = time.time()
#         print('Execution Time is:', t1-t0)                                              
#         plt.figure(1)

#         CostPlot(N_qubits, kernel_type, data_train_test, N_samples, cost_func, loss, circuit_params, born_probs_list, empirical_probs_list)
        

#         fig, axs = PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict)
#         SaveAnimation(5, fig, N_epochs, N_qubits,  N_born_samples, cost_func, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples)
        

#         PrintFinalParamsToFile(cost_func, data_type, data_circuit_choice, N_epochs, \
#                                 learning_rate, loss, circuit_params, data_exact_dict, born_probs_list, empirical_probs_list, \
#                                 qc, kernel_type, N_samples, stein_params, sinkhorn_eps, run)

# if __name__ == "__main__":

#     main()

# %%
if 2 != 2:
    sys.exit("[ERROR] : There should be exactly one input. Namely, a txt file containing the input values. Please see the README.md file for more details.")
else:
    N_epochs, learning_rate, data_type, N_samples, kernel_type,cost_func, device_name, as_qvm_value, stein_params, sinkhorn_eps, run = get_inputs('./inputs.txt')

    if type(device_name) is not str:
            raise ValueError('The device name must be a string')
    if (as_qvm_value is not True and as_qvm_value is not False):
            raise ValueError('\'as_qvm_value\' must be an integer, either 0, or 1')

    qc = get_qc(device_name, as_qvm = as_qvm_value)  
    N_qubits = len(qc.qubits())
    data_circuit_choice = 'IQP'

    N_data_samples = N_samples[0]
    N_born_samples = N_samples[1]

    if data_type == 'Quantum_Data':

        try:
            data_samples= list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))
        except:
            PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
            data_samples = list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))

    elif data_type == 'Bernoulli_Data':

        try:
            with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
                data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

        except:
            PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
            with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
                data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

        print("read data =")
        data_samples_orig
        data_samples = np.zeros((N_data_samples, N_qubits), dtype = int)

        for sample in range(0, N_data_samples):

            temp = data_samples_orig[sample]

            for outcome in range(0, N_qubits):

                data_samples[sample, N_qubits - 1 - outcome] = temp % 2
                temp >>= 1

    else:
        sys.exit("[ERROR] : data_type should be either 'Quantum_Data' or 'Bernoulli_Data'")

    np.random.shuffle(data_samples)

    #Split data into training/test sets
    data_train_test = TrainTestPartition(data_samples)

    random_seed = 0

    #Parameters, J, b for epoch 0 at random, gamma = constant = pi/4
    #Set random seed to 0 to initialise the actual Born machine to be trained
    initial_params = NetworkParams(qc, random_seed)

    data_exact_dict = DataDictFromFile(data_type, N_qubits, 'infinite', data_circuit_choice)
    t0 = time.time()
    loss, circuit_params, born_probs_list, empirical_probs_list = TrainBorn(qc, cost_func, initial_params, \
                                                                        N_epochs, N_samples, data_train_test, data_exact_dict, \
                                                                        kernel_type, 'Precompute', learning_rate, \
                                                                        stein_params, sinkhorn_eps)


    t1 = time.time()
    print('Execution Time is:', t1-t0)                                              
    plt.figure(1)

#     CostPlot(N_qubits, kernel_type, data_train_test, N_samples, cost_func, loss, circuit_params, born_probs_list, empirical_probs_list)


#     fig, axs = PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict)
#     SaveAnimation(5, fig, N_epochs, N_qubits,  N_born_samples, cost_func, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples)


    PrintFinalParamsToFile(cost_func, data_type, data_circuit_choice, N_epochs, \
                            learning_rate, loss, circuit_params, data_exact_dict, born_probs_list, empirical_probs_list, \
                            qc, kernel_type, N_samples, stein_params, sinkhorn_eps, run)
# Out:
# read data =
# The lattice is: 2q-qvm
#
# This is Epoch number:  0
# The Born Machine Outputs Probabilites
#  {'00': 0.853, '01': 0.017, '10': 0.0335, '11': 0.0965}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  0 is 0.22238244180077138
# The Variation Distance for epoch  0 is 0.49012552413175164
# /Users/reza/projects/PycharmProjects/IsingBornMachine/sample_gen.py:35: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   born_samples = np.flip(np.vstack(born_samples_all_qubits_dict[q] for q in sorted(qc.qubits())).T, 1) #put outcomes into array
# /Users/reza/projects/PycharmProjects/IsingBornMachine/sample_gen.py:58: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   born_samples_pm.append(np.flip(np.vstack(born_samples_plus_all_qbs_dict[q] for q in sorted(qc.qubits())).T, 1))
# /Users/reza/projects/PycharmProjects/IsingBornMachine/sample_gen.py:59: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   born_samples_pm.append(np.flip(np.vstack(born_samples_minus_all_qbs_dict[q] for q in sorted(qc.qubits())).T, 1))
# This is Epoch number:  1
# The Born Machine Outputs Probabilites
#  {'00': 0.84, '01': 0.0185, '10': 0.031, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  1 is 0.2132182238851552
# The Variation Distance for epoch  1 is 0.4899691079319478
#
# This is Epoch number:  2
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.0175, '10': 0.032, '11': 0.0985}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2 is 0.22143428803984055
# The Variation Distance for epoch  2 is 0.4898128948624361
#
# This is Epoch number:  3
# The Born Machine Outputs Probabilites
#  {'00': 0.8395, '01': 0.0205, '10': 0.0345, '11': 0.1055}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  3 is 0.21358302011735186
# The Variation Distance for epoch  3 is 0.4896569809085567
#
# This is Epoch number:  4
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.016, '10': 0.0325, '11': 0.0995}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  4 is 0.22147519912436409
# The Variation Distance for epoch  4 is 0.48950090959051795
#
# This is Epoch number:  5
# The Born Machine Outputs Probabilites
#  {'00': 0.854, '01': 0.015, '10': 0.033, '11': 0.098}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  5 is 0.22289722218988695
# The Variation Distance for epoch  5 is 0.48934461436246324
#
# This is Epoch number:  6
# The Born Machine Outputs Probabilites
#  {'00': 0.859, '01': 0.0095, '10': 0.0285, '11': 0.103}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  6 is 0.22528490071908158
# The Variation Distance for epoch  6 is 0.48918904573906025
#
# This is Epoch number:  7
# The Born Machine Outputs Probabilites
#  {'00': 0.8375, '01': 0.014, '10': 0.038, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  7 is 0.21271367186570278
# The Variation Distance for epoch  7 is 0.48903367593588687
#
# This is Epoch number:  8
# The Born Machine Outputs Probabilites
#  {'00': 0.851, '01': 0.015, '10': 0.0335, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  8 is 0.22095046754757908
# The Variation Distance for epoch  8 is 0.4888791732426653
#
# This is Epoch number:  9
# The Born Machine Outputs Probabilites
#  {'00': 0.855, '01': 0.0165, '10': 0.032, '11': 0.0965}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  9 is 0.2234447838583148
# The Variation Distance for epoch  9 is 0.48872434389770686
#
# This is Epoch number:  10
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.0165, '10': 0.0365, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  10 is 0.21549801941553537
# The Variation Distance for epoch  10 is 0.4885683286981166
#
# This is Epoch number:  11
# The Born Machine Outputs Probabilites
#  {'00': 0.855, '01': 0.0165, '10': 0.034, '11': 0.0945}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  11 is 0.2238280135222327
# The Variation Distance for epoch  11 is 0.48841215800082405
#
# This is Epoch number:  12
# The Born Machine Outputs Probabilites
#  {'00': 0.8315, '01': 0.0145, '10': 0.039, '11': 0.115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  12 is 0.20896061950322498
# The Variation Distance for epoch  12 is 0.4882567985501147
#
# This is Epoch number:  13
# The Born Machine Outputs Probabilites
#  {'00': 0.847, '01': 0.0115, '10': 0.038, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  13 is 0.2189888341011983
# The Variation Distance for epoch  13 is 0.4881012843723824
#
# This is Epoch number:  14
# The Born Machine Outputs Probabilites
#  {'00': 0.8525, '01': 0.017, '10': 0.0345, '11': 0.096}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  14 is 0.2222325005903557
# The Variation Distance for epoch  14 is 0.48794579959528983
#
# This is Epoch number:  15
# The Born Machine Outputs Probabilites
#  {'00': 0.8395, '01': 0.0165, '10': 0.024, '11': 0.12}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  15 is 0.2116164262752348
# The Variation Distance for epoch  15 is 0.4877894348105175
#
# This is Epoch number:  16
# The Born Machine Outputs Probabilites
#  {'00': 0.8615, '01': 0.016, '10': 0.0255, '11': 0.097}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  16 is 0.22666136526867797
# The Variation Distance for epoch  16 is 0.4876324549318256
#
# This is Epoch number:  17
# The Born Machine Outputs Probabilites
#  {'00': 0.8495, '01': 0.018, '10': 0.028, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  17 is 0.21901555753741997
# The Variation Distance for epoch  17 is 0.4874749850939919
#
# This is Epoch number:  18
# The Born Machine Outputs Probabilites
#  {'00': 0.8635, '01': 0.0175, '10': 0.0305, '11': 0.0885}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  18 is 0.22906277330684177
# The Variation Distance for epoch  18 is 0.48731705124247093
#
# This is Epoch number:  19
# The Born Machine Outputs Probabilites
#  {'00': 0.851, '01': 0.016, '10': 0.029, '11': 0.104}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  19 is 0.22014585555945787
# The Variation Distance for epoch  19 is 0.487157964509523
#
# This is Epoch number:  20
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.02, '10': 0.03, '11': 0.0985}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  20 is 0.22081123438016892
# The Variation Distance for epoch  20 is 0.48699873302425045
#
# This is Epoch number:  21
# The Born Machine Outputs Probabilites
#  {'00': 0.8615, '01': 0.0175, '10': 0.026, '11': 0.095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  21 is 0.22681394157263768
# The Variation Distance for epoch  21 is 0.48684037131862606
#
# This is Epoch number:  22
# The Born Machine Outputs Probabilites
#  {'00': 0.8465, '01': 0.017, '10': 0.033, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  22 is 0.21788146810636322
# The Variation Distance for epoch  22 is 0.48668146599318046
#
# This is Epoch number:  23
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.0195, '10': 0.034, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  23 is 0.2168053655582135
# The Variation Distance for epoch  23 is 0.4865220411512464
#
# This is Epoch number:  24
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.015, '10': 0.0355, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  24 is 0.21895911167649817
# The Variation Distance for epoch  24 is 0.4863622531831284
#
# This is Epoch number:  25
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.015, '10': 0.0325, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  25 is 0.2214409813327144
# The Variation Distance for epoch  25 is 0.48620360516721306
#
# This is Epoch number:  26
# The Born Machine Outputs Probabilites
#  {'00': 0.841, '01': 0.019, '10': 0.0365, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  26 is 0.2149075728958274
# The Variation Distance for epoch  26 is 0.4860457831289306
#
# This is Epoch number:  27
# The Born Machine Outputs Probabilites
#  {'00': 0.8395, '01': 0.0195, '10': 0.0345, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  27 is 0.21355130073653683
# The Variation Distance for epoch  27 is 0.4858883751777513
#
# This is Epoch number:  28
# The Born Machine Outputs Probabilites
#  {'00': 0.8505, '01': 0.016, '10': 0.0315, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  28 is 0.22026999099266864
# The Variation Distance for epoch  28 is 0.48573158064883964
#
# This is Epoch number:  29
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.0135, '10': 0.0315, '11': 0.103}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  29 is 0.2212051989720909
# The Variation Distance for epoch  29 is 0.48557508885933137
#
# This is Epoch number:  30
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.0175, '10': 0.0265, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  30 is 0.2157129000779453
# The Variation Distance for epoch  30 is 0.48541794093877494
#
# This is Epoch number:  31
# The Born Machine Outputs Probabilites
#  {'00': 0.8335, '01': 0.018, '10': 0.0375, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  31 is 0.21008447952393117
# The Variation Distance for epoch  31 is 0.4852613958665309
#
# This is Epoch number:  32
# The Born Machine Outputs Probabilites
#  {'00': 0.8495, '01': 0.0215, '10': 0.0315, '11': 0.0975}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  32 is 0.21979099197843088
# The Variation Distance for epoch  32 is 0.48510627746046164
#
# This is Epoch number:  33
# The Born Machine Outputs Probabilites
#  {'00': 0.8455, '01': 0.017, '10': 0.035, '11': 0.1025}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  33 is 0.2175815856855312
# The Variation Distance for epoch  33 is 0.4849520505423565
#
# This is Epoch number:  34
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.0205, '10': 0.0355, '11': 0.0995}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  34 is 0.21712273148147743
# The Variation Distance for epoch  34 is 0.48479701690080895
#
# This is Epoch number:  35
# The Born Machine Outputs Probabilites
#  {'00': 0.857, '01': 0.012, '10': 0.036, '11': 0.095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  35 is 0.22542207748318088
# The Variation Distance for epoch  35 is 0.4846412834207012
#
# This is Epoch number:  36
# The Born Machine Outputs Probabilites
#  {'00': 0.8465, '01': 0.0165, '10': 0.038, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  36 is 0.21880821607575407
# The Variation Distance for epoch  36 is 0.4844848552344691
#
# This is Epoch number:  37
# The Born Machine Outputs Probabilites
#  {'00': 0.8495, '01': 0.0185, '10': 0.0255, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  37 is 0.21857970215535805
# The Variation Distance for epoch  37 is 0.4843288642210087
#
# This is Epoch number:  38
# The Born Machine Outputs Probabilites
#  {'00': 0.8545, '01': 0.0185, '10': 0.0415, '11': 0.0855}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  38 is 0.22504907973021449
# The Variation Distance for epoch  38 is 0.48417416919475453
#
# This is Epoch number:  39
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.0165, '10': 0.038, '11': 0.1025}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  39 is 0.21644979823740396
# The Variation Distance for epoch  39 is 0.4840198143544558
#
# This is Epoch number:  40
# The Born Machine Outputs Probabilites
#  {'00': 0.8425, '01': 0.015, '10': 0.0415, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  40 is 0.21673402788477358
# The Variation Distance for epoch  40 is 0.48386574806275
#
# This is Epoch number:  41
# The Born Machine Outputs Probabilites
#  {'00': 0.849, '01': 0.0195, '10': 0.0305, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  41 is 0.21918970422684814
# The Variation Distance for epoch  41 is 0.48371114888656064
#
# This is Epoch number:  42
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.017, '10': 0.039, '11': 0.0995}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  42 is 0.21766596608887134
# The Variation Distance for epoch  42 is 0.4835574765579481
#
# This is Epoch number:  43
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.0145, '10': 0.0435, '11': 0.097}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  43 is 0.2187922363686784
# The Variation Distance for epoch  43 is 0.4834014688866905
#
# This is Epoch number:  44
# The Born Machine Outputs Probabilites
#  {'00': 0.8485, '01': 0.018, '10': 0.0325, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  44 is 0.21917126778474283
# The Variation Distance for epoch  44 is 0.4832465966555354
#
# This is Epoch number:  45
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.019, '10': 0.033, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  45 is 0.21660236219184592
# The Variation Distance for epoch  45 is 0.483092119730852
#
# This is Epoch number:  46
# The Born Machine Outputs Probabilites
#  {'00': 0.8485, '01': 0.016, '10': 0.0265, '11': 0.109}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  46 is 0.21800963165907938
# The Variation Distance for epoch  46 is 0.48293844860199087
#
# This is Epoch number:  47
# The Born Machine Outputs Probabilites
#  {'00': 0.8485, '01': 0.016, '10': 0.0325, '11': 0.103}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  47 is 0.2191042064108425
# The Variation Distance for epoch  47 is 0.4827856197341315
#
# This is Epoch number:  48
# The Born Machine Outputs Probabilites
#  {'00': 0.844, '01': 0.016, '10': 0.031, '11': 0.109}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  48 is 0.21580874943518213
# The Variation Distance for epoch  48 is 0.48263212236795294
#
# This is Epoch number:  49
# The Born Machine Outputs Probabilites
#  {'00': 0.851, '01': 0.0165, '10': 0.0315, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  49 is 0.22062566081075452
# The Variation Distance for epoch  49 is 0.48247821592520784
#
# This is Epoch number:  50
# The Born Machine Outputs Probabilites
#  {'00': 0.8225, '01': 0.018, '10': 0.043, '11': 0.1165}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  50 is 0.2039073501362204
# The Variation Distance for epoch  50 is 0.4823234755102355
#
# This is Epoch number:  51
# The Born Machine Outputs Probabilites
#  {'00': 0.86, '01': 0.0185, '10': 0.0305, '11': 0.091}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  51 is 0.2266772063797664
# The Variation Distance for epoch  51 is 0.48216899641603594
#
# This is Epoch number:  52
# The Born Machine Outputs Probabilites
#  {'00': 0.849, '01': 0.0175, '10': 0.033, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  52 is 0.21958596920378004
# The Variation Distance for epoch  52 is 0.48201345596766615
#
# This is Epoch number:  53
# The Born Machine Outputs Probabilites
#  {'00': 0.85, '01': 0.0185, '10': 0.04, '11': 0.0915}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  53 is 0.22165284160890664
# The Variation Distance for epoch  53 is 0.48185738227877456
#
# This is Epoch number:  54
# The Born Machine Outputs Probabilites
#  {'00': 0.838, '01': 0.0185, '10': 0.032, '11': 0.1115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  54 is 0.21207284057116238
# The Variation Distance for epoch  54 is 0.48170062716514644
#
# This is Epoch number:  55
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.014, '10': 0.035, '11': 0.106}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  55 is 0.21715389413050235
# The Variation Distance for epoch  55 is 0.48154407399820714
#
# This is Epoch number:  56
# The Born Machine Outputs Probabilites
#  {'00': 0.8315, '01': 0.02, '10': 0.0345, '11': 0.114}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  56 is 0.20828268627534885
# The Variation Distance for epoch  56 is 0.48138662407530997
#
# This is Epoch number:  57
# The Born Machine Outputs Probabilites
#  {'00': 0.846, '01': 0.0175, '10': 0.035, '11': 0.1015}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  57 is 0.21793496735905038
# The Variation Distance for epoch  57 is 0.4812282078809599
#
# This is Epoch number:  58
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.022, '10': 0.035, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  58 is 0.20941336971287738
# The Variation Distance for epoch  58 is 0.4810686777004435
#
# This is Epoch number:  59
# The Born Machine Outputs Probabilites
#  {'00': 0.8335, '01': 0.015, '10': 0.029, '11': 0.1225}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  59 is 0.20851692776125108
# The Variation Distance for epoch  59 is 0.4809095989158333
#
# This is Epoch number:  60
# The Born Machine Outputs Probabilites
#  {'00': 0.8425, '01': 0.02, '10': 0.047, '11': 0.0905}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  60 is 0.2179951767963222
# The Variation Distance for epoch  60 is 0.4807520724904928
#
# This is Epoch number:  61
# The Born Machine Outputs Probabilites
#  {'00': 0.838, '01': 0.0145, '10': 0.0375, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  61 is 0.21296525918966314
# The Variation Distance for epoch  61 is 0.4805915197603604
#
# This is Epoch number:  62
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.019, '10': 0.039, '11': 0.106}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  62 is 0.21204222301787556
# The Variation Distance for epoch  62 is 0.4804323146539809
#
# This is Epoch number:  63
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.027, '10': 0.0355, '11': 0.0955}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  63 is 0.21569164756890036
# The Variation Distance for epoch  63 is 0.48027362441218574
#
# This is Epoch number:  64
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.016, '10': 0.03, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  64 is 0.217970405769623
# The Variation Distance for epoch  64 is 0.4801159880999447
#
# This is Epoch number:  65
# The Born Machine Outputs Probabilites
#  {'00': 0.839, '01': 0.019, '10': 0.0325, '11': 0.1095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  65 is 0.21283933829911283
# The Variation Distance for epoch  65 is 0.4799587303292767
#
# This is Epoch number:  66
# The Born Machine Outputs Probabilites
#  {'00': 0.855, '01': 0.023, '10': 0.0285, '11': 0.0935}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  66 is 0.22304295129513652
# The Variation Distance for epoch  66 is 0.47980191029810426
#
# This is Epoch number:  67
# The Born Machine Outputs Probabilites
#  {'00': 0.8335, '01': 0.018, '10': 0.0405, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  67 is 0.21063716113843745
# The Variation Distance for epoch  67 is 0.47964557611647124
#
# This is Epoch number:  68
# The Born Machine Outputs Probabilites
#  {'00': 0.8505, '01': 0.0175, '10': 0.031, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  68 is 0.22022786132792205
# The Variation Distance for epoch  68 is 0.47948814535083495
#
# This is Epoch number:  69
# The Born Machine Outputs Probabilites
#  {'00': 0.8385, '01': 0.023, '10': 0.033, '11': 0.1055}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  69 is 0.21272404014660695
# The Variation Distance for epoch  69 is 0.47933188051414777
#
# This is Epoch number:  70
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.02, '10': 0.035, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  70 is 0.21034391191433577
# The Variation Distance for epoch  70 is 0.47917595779256084
#
# This is Epoch number:  71
# The Born Machine Outputs Probabilites
#  {'00': 0.844, '01': 0.017, '10': 0.0385, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  71 is 0.2172333858792701
# The Variation Distance for epoch  71 is 0.47902040031900733
#
# This is Epoch number:  72
# The Born Machine Outputs Probabilites
#  {'00': 0.8425, '01': 0.017, '10': 0.0375, '11': 0.103}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  72 is 0.21603581538266203
# The Variation Distance for epoch  72 is 0.4788637028497584
#
# This is Epoch number:  73
# The Born Machine Outputs Probabilites
#  {'00': 0.844, '01': 0.017, '10': 0.0405, '11': 0.0985}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  73 is 0.21761714868751414
# The Variation Distance for epoch  73 is 0.4787067148720082
#
# This is Epoch number:  74
# The Born Machine Outputs Probabilites
#  {'00': 0.8435, '01': 0.0195, '10': 0.038, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  74 is 0.21688735682490257
# The Variation Distance for epoch  74 is 0.4785485185558641
#
# This is Epoch number:  75
# The Born Machine Outputs Probabilites
#  {'00': 0.8435, '01': 0.014, '10': 0.031, '11': 0.1115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  75 is 0.21542174441926532
# The Variation Distance for epoch  75 is 0.4783907777970688
#
# This is Epoch number:  76
# The Born Machine Outputs Probabilites
#  {'00': 0.841, '01': 0.014, '10': 0.0345, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  76 is 0.21439320906904302
# The Variation Distance for epoch  76 is 0.47823368999568017
#
# This is Epoch number:  77
# The Born Machine Outputs Probabilites
#  {'00': 0.8545, '01': 0.015, '10': 0.0335, '11': 0.097}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  77 is 0.22333403513627148
# The Variation Distance for epoch  77 is 0.47807634053417375
#
# This is Epoch number:  78
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.017, '10': 0.033, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  78 is 0.21486700106622636
# The Variation Distance for epoch  78 is 0.47791797673351943
#
# This is Epoch number:  79
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.0185, '10': 0.039, '11': 0.0995}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  79 is 0.21670636844297453
# The Variation Distance for epoch  79 is 0.47776046219152274
#
# This is Epoch number:  80
# The Born Machine Outputs Probabilites
#  {'00': 0.8565, '01': 0.0135, '10': 0.034, '11': 0.096}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  80 is 0.2247453890660831
# The Variation Distance for epoch  80 is 0.47760189924577096
#
# This is Epoch number:  81
# The Born Machine Outputs Probabilites
#  {'00': 0.826, '01': 0.02, '10': 0.0425, '11': 0.1115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  81 is 0.206136898131708
# The Variation Distance for epoch  81 is 0.4774427973891279
#
# This is Epoch number:  82
# The Born Machine Outputs Probabilites
#  {'00': 0.8335, '01': 0.021, '10': 0.036, '11': 0.1095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  82 is 0.20989489761139568
# The Variation Distance for epoch  82 is 0.4772839830509701
#
# This is Epoch number:  83
# The Born Machine Outputs Probabilites
#  {'00': 0.851, '01': 0.022, '10': 0.0315, '11': 0.0955}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  83 is 0.22083228969070234
# The Variation Distance for epoch  83 is 0.4771242671538539
#
# This is Epoch number:  84
# The Born Machine Outputs Probabilites
#  {'00': 0.8265, '01': 0.0215, '10': 0.0415, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  84 is 0.20631973089363287
# The Variation Distance for epoch  84 is 0.47696309636392065
#
# This is Epoch number:  85
# The Born Machine Outputs Probabilites
#  {'00': 0.839, '01': 0.015, '10': 0.0425, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  85 is 0.21458103489797553
# The Variation Distance for epoch  85 is 0.47680300476764464
#
# This is Epoch number:  86
# The Born Machine Outputs Probabilites
#  {'00': 0.8375, '01': 0.017, '10': 0.0335, '11': 0.112}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  86 is 0.2119714331849608
# The Variation Distance for epoch  86 is 0.47664368755361947
#
# This is Epoch number:  87
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.018, '10': 0.043, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  87 is 0.21143745485031928
# The Variation Distance for epoch  87 is 0.47648391631583525
#
# This is Epoch number:  88
# The Born Machine Outputs Probabilites
#  {'00': 0.8455, '01': 0.0145, '10': 0.0325, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  88 is 0.217042075227862
# The Variation Distance for epoch  88 is 0.476324528442046
#
# This is Epoch number:  89
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.0155, '10': 0.036, '11': 0.0965}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  89 is 0.22212462612549455
# The Variation Distance for epoch  89 is 0.47616520853125816
#
# This is Epoch number:  90
# The Born Machine Outputs Probabilites
#  {'00': 0.848, '01': 0.0155, '10': 0.043, '11': 0.0935}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  90 is 0.22076577398611863
# The Variation Distance for epoch  90 is 0.4760035936442623
#
# This is Epoch number:  91
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.0175, '10': 0.0335, '11': 0.1015}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  91 is 0.21866550029266352
# The Variation Distance for epoch  91 is 0.47584198689415647
#
# This is Epoch number:  92
# The Born Machine Outputs Probabilites
#  {'00': 0.8455, '01': 0.0195, '10': 0.033, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  92 is 0.21729194213511993
# The Variation Distance for epoch  92 is 0.47568017122030454
#
# This is Epoch number:  93
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.018, '10': 0.039, '11': 0.1}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  93 is 0.21668919248690865
# The Variation Distance for epoch  93 is 0.4755187132962337
#
# This is Epoch number:  94
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.022, '10': 0.04, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  94 is 0.21033357029319455
# The Variation Distance for epoch  94 is 0.4753565849328002
#
# This is Epoch number:  95
# The Born Machine Outputs Probabilites
#  {'00': 0.8425, '01': 0.015, '10': 0.034, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  95 is 0.21532649530652248
# The Variation Distance for epoch  95 is 0.47519381637660446
#
# This is Epoch number:  96
# The Born Machine Outputs Probabilites
#  {'00': 0.835, '01': 0.0185, '10': 0.038, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  96 is 0.21117961570113664
# The Variation Distance for epoch  96 is 0.47503226856533565
#
# This is Epoch number:  97
# The Born Machine Outputs Probabilites
#  {'00': 0.85, '01': 0.0205, '10': 0.035, '11': 0.0945}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  97 is 0.22075812338974488
# The Variation Distance for epoch  97 is 0.4748713060023802
#
# This is Epoch number:  98
# The Born Machine Outputs Probabilites
#  {'00': 0.8315, '01': 0.015, '10': 0.0385, '11': 0.115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  98 is 0.20888103850749895
# The Variation Distance for epoch  98 is 0.47471138881221675
#
# This is Epoch number:  99
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.0155, '10': 0.035, '11': 0.1155}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  99 is 0.2099006207058819
# The Variation Distance for epoch  99 is 0.47455031358983324
#
# This is Epoch number:  100
# The Born Machine Outputs Probabilites
#  {'00': 0.8395, '01': 0.018, '10': 0.0375, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  100 is 0.2140606550530506
# The Variation Distance for epoch  100 is 0.4743892357630583
#
# This is Epoch number:  101
# The Born Machine Outputs Probabilites
#  {'00': 0.8315, '01': 0.0175, '10': 0.036, '11': 0.115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  101 is 0.20848852276108487
# The Variation Distance for epoch  101 is 0.4742282227349565
#
# This is Epoch number:  102
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.0195, '10': 0.0325, '11': 0.1135}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  102 is 0.2098816303360851
# The Variation Distance for epoch  102 is 0.47406769648894964
#
# This is Epoch number:  103
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.0175, '10': 0.048, '11': 0.1}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  103 is 0.21271742731170196
# The Variation Distance for epoch  103 is 0.47390849829787757
#
# This is Epoch number:  104
# The Born Machine Outputs Probabilites
#  {'00': 0.826, '01': 0.02, '10': 0.0365, '11': 0.1175}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  104 is 0.20505421436419313
# The Variation Distance for epoch  104 is 0.4737495617342576
#
# This is Epoch number:  105
# The Born Machine Outputs Probabilites
#  {'00': 0.8505, '01': 0.0175, '10': 0.0345, '11': 0.0975}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  105 is 0.22088787965017587
# The Variation Distance for epoch  105 is 0.47359045130653343
#
# This is Epoch number:  106
# The Born Machine Outputs Probabilites
#  {'00': 0.824, '01': 0.026, '10': 0.0355, '11': 0.1145}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  106 is 0.2037341185599295
# The Variation Distance for epoch  106 is 0.473433248627005
#
# This is Epoch number:  107
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.0195, '10': 0.0395, '11': 0.096}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  107 is 0.2181896671295429
# The Variation Distance for epoch  107 is 0.47327643204226855
#
# This is Epoch number:  108
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.022, '10': 0.0355, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  108 is 0.21148779524694494
# The Variation Distance for epoch  108 is 0.47311926931036213
#
# This is Epoch number:  109
# The Born Machine Outputs Probabilites
#  {'00': 0.818, '01': 0.024, '10': 0.0435, '11': 0.1145}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  109 is 0.20123359209558167
# The Variation Distance for epoch  109 is 0.47296238841540456
#
# This is Epoch number:  110
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.021, '10': 0.0355, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  110 is 0.20947464226900192
# The Variation Distance for epoch  110 is 0.47280501468178454
#
# This is Epoch number:  111
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.0175, '10': 0.037, '11': 0.1025}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  111 is 0.21629315122098602
# The Variation Distance for epoch  111 is 0.47264716710671895
#
# This is Epoch number:  112
# The Born Machine Outputs Probabilites
#  {'00': 0.8375, '01': 0.019, '10': 0.034, '11': 0.1095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  112 is 0.2121167253025481
# The Variation Distance for epoch  112 is 0.472488078138533
#
# This is Epoch number:  113
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.0155, '10': 0.0365, '11': 0.0965}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  113 is 0.22188003730118044
# The Variation Distance for epoch  113 is 0.47232846933383593
#
# This is Epoch number:  114
# The Born Machine Outputs Probabilites
#  {'00': 0.84, '01': 0.0205, '10': 0.0375, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  114 is 0.2144760002867161
# The Variation Distance for epoch  114 is 0.4721682462301488
#
# This is Epoch number:  115
# The Born Machine Outputs Probabilites
#  {'00': 0.8525, '01': 0.0175, '10': 0.035, '11': 0.095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  115 is 0.222347580877146
# The Variation Distance for epoch  115 is 0.47200767241846014
#
# This is Epoch number:  116
# The Born Machine Outputs Probabilites
#  {'00': 0.8365, '01': 0.0195, '10': 0.037, '11': 0.107}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  116 is 0.2120179107723683
# The Variation Distance for epoch  116 is 0.47184750379457585
#
# This is Epoch number:  117
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.017, '10': 0.037, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  117 is 0.2116155783450112
# The Variation Distance for epoch  117 is 0.4716877170701602
#
# This is Epoch number:  118
# The Born Machine Outputs Probabilites
#  {'00': 0.835, '01': 0.015, '10': 0.0345, '11': 0.1155}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  118 is 0.21045606273327366
# The Variation Distance for epoch  118 is 0.4715285981477289
#
# This is Epoch number:  119
# The Born Machine Outputs Probabilites
#  {'00': 0.8285, '01': 0.0205, '10': 0.0405, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  119 is 0.20741717743756394
# The Variation Distance for epoch  119 is 0.47136993563152874
#
# This is Epoch number:  120
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.0205, '10': 0.041, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  120 is 0.2111362290088934
# The Variation Distance for epoch  120 is 0.4712108761079526
#
# This is Epoch number:  121
# The Born Machine Outputs Probabilites
#  {'00': 0.85, '01': 0.014, '10': 0.034, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  121 is 0.22033446263000545
# The Variation Distance for epoch  121 is 0.47105238256125104
#
# This is Epoch number:  122
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.014, '10': 0.0405, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  122 is 0.21119341059532393
# The Variation Distance for epoch  122 is 0.47089453414667837
#
# This is Epoch number:  123
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.0185, '10': 0.0275, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  123 is 0.21759495592522693
# The Variation Distance for epoch  123 is 0.47073792004340614
#
# This is Epoch number:  124
# The Born Machine Outputs Probabilites
#  {'00': 0.832, '01': 0.0165, '10': 0.039, '11': 0.1125}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  124 is 0.20933402893782382
# The Variation Distance for epoch  124 is 0.47058018870080803
#
# This is Epoch number:  125
# The Born Machine Outputs Probabilites
#  {'00': 0.838, '01': 0.026, '10': 0.0285, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  125 is 0.2116810462903539
# The Variation Distance for epoch  125 is 0.4704224356119752
#
# This is Epoch number:  126
# The Born Machine Outputs Probabilites
#  {'00': 0.8355, '01': 0.0195, '10': 0.038, '11': 0.107}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  126 is 0.21153980133783146
# The Variation Distance for epoch  126 is 0.47026273204078645
#
# This is Epoch number:  127
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.0235, '10': 0.033, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  127 is 0.211079914905137
# The Variation Distance for epoch  127 is 0.47010196048202413
#
# This is Epoch number:  128
# The Born Machine Outputs Probabilites
#  {'00': 0.839, '01': 0.018, '10': 0.0345, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  128 is 0.213173760337103
# The Variation Distance for epoch  128 is 0.4699404790327037
#
# This is Epoch number:  129
# The Born Machine Outputs Probabilites
#  {'00': 0.8225, '01': 0.0165, '10': 0.04, '11': 0.121}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  129 is 0.2033408876221231
# The Variation Distance for epoch  129 is 0.4697792207596382
#
# This is Epoch number:  130
# The Born Machine Outputs Probabilites
#  {'00': 0.8405, '01': 0.0215, '10': 0.036, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  130 is 0.21456369953434684
# The Variation Distance for epoch  130 is 0.46961808665790344
#
# This is Epoch number:  131
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.017, '10': 0.0375, '11': 0.0935}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  131 is 0.2224713670336489
# The Variation Distance for epoch  131 is 0.469456905865312
#
# This is Epoch number:  132
# The Born Machine Outputs Probabilites
#  {'00': 0.823, '01': 0.023, '10': 0.038, '11': 0.116}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  132 is 0.20344935521837948
# The Variation Distance for epoch  132 is 0.46929635540146425
#
# This is Epoch number:  133
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.0155, '10': 0.041, '11': 0.0985}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  133 is 0.2183383124950018
# The Variation Distance for epoch  133 is 0.46913459129861795
#
# This is Epoch number:  134
# The Born Machine Outputs Probabilites
#  {'00': 0.8285, '01': 0.0175, '10': 0.037, '11': 0.117}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  134 is 0.20671010831465908
# The Variation Distance for epoch  134 is 0.46897282532784784
#
# This is Epoch number:  135
# The Born Machine Outputs Probabilites
#  {'00': 0.828, '01': 0.0175, '10': 0.044, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  135 is 0.20765801853655164
# The Variation Distance for epoch  135 is 0.46881098743334243
#
# This is Epoch number:  136
# The Born Machine Outputs Probabilites
#  {'00': 0.8355, '01': 0.0195, '10': 0.041, '11': 0.104}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  136 is 0.21210087228011942
# The Variation Distance for epoch  136 is 0.468650343643591
#
# This is Epoch number:  137
# The Born Machine Outputs Probabilites
#  {'00': 0.844, '01': 0.0185, '10': 0.033, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  137 is 0.21625036300982603
# The Variation Distance for epoch  137 is 0.46848978085109366
#
# This is Epoch number:  138
# The Born Machine Outputs Probabilites
#  {'00': 0.846, '01': 0.0185, '10': 0.032, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  138 is 0.21740889902950544
# The Variation Distance for epoch  138 is 0.4683309869854288
#
# This is Epoch number:  139
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.019, '10': 0.035, '11': 0.1115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  139 is 0.2103161446371462
# The Variation Distance for epoch  139 is 0.46817049946035205
#
# This is Epoch number:  140
# The Born Machine Outputs Probabilites
#  {'00': 0.8255, '01': 0.0225, '10': 0.0455, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  140 is 0.20643918183531562
# The Variation Distance for epoch  140 is 0.4680107981762891
#
# This is Epoch number:  141
# The Born Machine Outputs Probabilites
#  {'00': 0.832, '01': 0.0265, '10': 0.0285, '11': 0.113}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  141 is 0.20773758939403975
# The Variation Distance for epoch  141 is 0.4678516231779608
#
# This is Epoch number:  142
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.0235, '10': 0.0395, '11': 0.1025}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  142 is 0.21128572873979645
# The Variation Distance for epoch  142 is 0.4676921812121031
#
# This is Epoch number:  143
# The Born Machine Outputs Probabilites
#  {'00': 0.839, '01': 0.017, '10': 0.04, '11': 0.104}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  143 is 0.21416595396327898
# The Variation Distance for epoch  143 is 0.4675345691012965
#
# This is Epoch number:  144
# The Born Machine Outputs Probabilites
#  {'00': 0.8405, '01': 0.015, '10': 0.0355, '11': 0.109}
# The Data is
# ...
# The MMD Loss for epoch  2450 is 0.0722510135980865
# The Variation Distance for epoch  2450 is 0.14409017690663625
#
# This is Epoch number:  2451
# The Born Machine Outputs Probabilites
#  {'00': 0.52, '01': 0.1155, '10': 0.1295, '11': 0.235}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2451 is 0.06641028429302087
# The Variation Distance for epoch  2451 is 0.1440026070765604
#
# This is Epoch number:  2452
# The Born Machine Outputs Probabilites
#  {'00': 0.5145, '01': 0.1135, '10': 0.1405, '11': 0.2315}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2452 is 0.06593540918216267
# The Variation Distance for epoch  2452 is 0.14391428346432883
#
# This is Epoch number:  2453
# The Born Machine Outputs Probabilites
#  {'00': 0.527, '01': 0.1235, '10': 0.1435, '11': 0.206}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2453 is 0.07055863581421773
# The Variation Distance for epoch  2453 is 0.14382622110987656
#
# This is Epoch number:  2454
# The Born Machine Outputs Probabilites
#  {'00': 0.516, '01': 0.121, '10': 0.1385, '11': 0.2245}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2454 is 0.06597157860245806
# The Variation Distance for epoch  2454 is 0.14373980591400007
#
# This is Epoch number:  2455
# The Born Machine Outputs Probabilites
#  {'00': 0.537, '01': 0.1105, '10': 0.13, '11': 0.2225}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2455 is 0.07265425401781489
# The Variation Distance for epoch  2455 is 0.143653206690588
#
# This is Epoch number:  2456
# The Born Machine Outputs Probabilites
#  {'00': 0.5225, '01': 0.1095, '10': 0.1385, '11': 0.2295}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2456 is 0.06859031145115557
# The Variation Distance for epoch  2456 is 0.14356661367421347
#
# This is Epoch number:  2457
# The Born Machine Outputs Probabilites
#  {'00': 0.5505, '01': 0.0985, '10': 0.123, '11': 0.228}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2457 is 0.07712398733526149
# The Variation Distance for epoch  2457 is 0.14347948951893338
#
# This is Epoch number:  2458
# The Born Machine Outputs Probabilites
#  {'00': 0.528, '01': 0.1115, '10': 0.14, '11': 0.2205}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2458 is 0.07067650395323088
# The Variation Distance for epoch  2458 is 0.14339185009495453
#
# This is Epoch number:  2459
# The Born Machine Outputs Probabilites
#  {'00': 0.532, '01': 0.115, '10': 0.1385, '11': 0.2145}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2459 is 0.07184136398268126
# The Variation Distance for epoch  2459 is 0.14330351496906749
#
# This is Epoch number:  2460
# The Born Machine Outputs Probabilites
#  {'00': 0.5195, '01': 0.11, '10': 0.145, '11': 0.2255}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2460 is 0.0683728249316562
# The Variation Distance for epoch  2460 is 0.1432152803517947
#
# This is Epoch number:  2461
# The Born Machine Outputs Probabilites
#  {'00': 0.5465, '01': 0.115, '10': 0.1275, '11': 0.211}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2461 is 0.07576772835121015
# The Variation Distance for epoch  2461 is 0.14312777592797285
#
# This is Epoch number:  2462
# The Born Machine Outputs Probabilites
#  {'00': 0.5245, '01': 0.1135, '10': 0.133, '11': 0.229}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2462 is 0.0684650815748985
# The Variation Distance for epoch  2462 is 0.14304010952712906
#
# This is Epoch number:  2463
# The Born Machine Outputs Probabilites
#  {'00': 0.5245, '01': 0.1235, '10': 0.136, '11': 0.216}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2463 is 0.0686055658481306
# The Variation Distance for epoch  2463 is 0.14295257022582575
#
# This is Epoch number:  2464
# The Born Machine Outputs Probabilites
#  {'00': 0.5335, '01': 0.121, '10': 0.1335, '11': 0.212}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2464 is 0.07160178790295635
# The Variation Distance for epoch  2464 is 0.1428658455657712
#
# This is Epoch number:  2465
# The Born Machine Outputs Probabilites
#  {'00': 0.5235, '01': 0.135, '10': 0.1225, '11': 0.219}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2465 is 0.066359194518268
# The Variation Distance for epoch  2465 is 0.14277877319579557
#
# This is Epoch number:  2466
# The Born Machine Outputs Probabilites
#  {'00': 0.5345, '01': 0.1095, '10': 0.134, '11': 0.222}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2466 is 0.07228956186924107
# The Variation Distance for epoch  2466 is 0.14269160562325617
#
# This is Epoch number:  2467
# The Born Machine Outputs Probabilites
#  {'00': 0.5385, '01': 0.113, '10': 0.1305, '11': 0.218}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2467 is 0.07320662955136581
# The Variation Distance for epoch  2467 is 0.14260326441982918
#
# This is Epoch number:  2468
# The Born Machine Outputs Probabilites
#  {'00': 0.53, '01': 0.116, '10': 0.1435, '11': 0.2105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2468 is 0.07178440447086176
# The Variation Distance for epoch  2468 is 0.14251468718945617
#
# This is Epoch number:  2469
# The Born Machine Outputs Probabilites
#  {'00': 0.52, '01': 0.1185, '10': 0.1345, '11': 0.227}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2469 is 0.06692649424079078
# The Variation Distance for epoch  2469 is 0.1424257694507576
#
# This is Epoch number:  2470
# The Born Machine Outputs Probabilites
#  {'00': 0.544, '01': 0.1085, '10': 0.143, '11': 0.2045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2470 is 0.0771169957337492
# The Variation Distance for epoch  2470 is 0.14233770982154473
#
# This is Epoch number:  2471
# The Born Machine Outputs Probabilites
#  {'00': 0.5475, '01': 0.1105, '10': 0.1295, '11': 0.2125}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2471 is 0.07650040619240517
# The Variation Distance for epoch  2471 is 0.1422503631069823
#
# This is Epoch number:  2472
# The Born Machine Outputs Probabilites
#  {'00': 0.519, '01': 0.1265, '10': 0.1365, '11': 0.218}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2472 is 0.0666482232591934
# The Variation Distance for epoch  2472 is 0.14216291861187505
#
# This is Epoch number:  2473
# The Born Machine Outputs Probabilites
#  {'00': 0.5345, '01': 0.109, '10': 0.1355, '11': 0.221}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2473 is 0.07250136377841643
# The Variation Distance for epoch  2473 is 0.14207543484871157
#
# This is Epoch number:  2474
# The Born Machine Outputs Probabilites
#  {'00': 0.5115, '01': 0.1205, '10': 0.158, '11': 0.21}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2474 is 0.06710765757751758
# The Variation Distance for epoch  2474 is 0.1419877896761889
#
# This is Epoch number:  2475
# The Born Machine Outputs Probabilites
#  {'00': 0.533, '01': 0.12, '10': 0.138, '11': 0.209}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2475 is 0.07205078963244471
# The Variation Distance for epoch  2475 is 0.14190106082972304
#
# This is Epoch number:  2476
# The Born Machine Outputs Probabilites
#  {'00': 0.516, '01': 0.1185, '10': 0.1395, '11': 0.226}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2476 is 0.06616772410415639
# The Variation Distance for epoch  2476 is 0.141813928550557
#
# This is Epoch number:  2477
# The Born Machine Outputs Probabilites
#  {'00': 0.5365, '01': 0.117, '10': 0.137, '11': 0.2095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2477 is 0.07326404643191231
# The Variation Distance for epoch  2477 is 0.14172692110732765
#
# This is Epoch number:  2478
# The Born Machine Outputs Probabilites
#  {'00': 0.5395, '01': 0.1035, '10': 0.1335, '11': 0.2235}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2478 is 0.07423294808214265
# The Variation Distance for epoch  2478 is 0.14163976802662423
#
# This is Epoch number:  2479
# The Born Machine Outputs Probabilites
#  {'00': 0.533, '01': 0.1105, '10': 0.1325, '11': 0.224}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2479 is 0.07152232016608628
# The Variation Distance for epoch  2479 is 0.1415524832333024
#
# This is Epoch number:  2480
# The Born Machine Outputs Probabilites
#  {'00': 0.538, '01': 0.1185, '10': 0.129, '11': 0.2145}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2480 is 0.07271159510193104
# The Variation Distance for epoch  2480 is 0.14146572397420934
#
# This is Epoch number:  2481
# The Born Machine Outputs Probabilites
#  {'00': 0.5165, '01': 0.1225, '10': 0.141, '11': 0.22}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2481 is 0.06643818772968257
# The Variation Distance for epoch  2481 is 0.14137852952979554
#
# This is Epoch number:  2482
# The Born Machine Outputs Probabilites
#  {'00': 0.539, '01': 0.1095, '10': 0.125, '11': 0.2265}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2482 is 0.0727833051955803
# The Variation Distance for epoch  2482 is 0.1412920282466297
#
# This is Epoch number:  2483
# The Born Machine Outputs Probabilites
#  {'00': 0.5085, '01': 0.1215, '10': 0.1385, '11': 0.2315}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2483 is 0.06338150166269141
# The Variation Distance for epoch  2483 is 0.14120494432825112
#
# This is Epoch number:  2484
# The Born Machine Outputs Probabilites
#  {'00': 0.54, '01': 0.1095, '10': 0.1415, '11': 0.209}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2484 is 0.0753576621882297
# The Variation Distance for epoch  2484 is 0.1411185393708093
#
# This is Epoch number:  2485
# The Born Machine Outputs Probabilites
#  {'00': 0.5025, '01': 0.1285, '10': 0.1385, '11': 0.2305}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2485 is 0.06116439567653165
# The Variation Distance for epoch  2485 is 0.14103103435055211
#
# This is Epoch number:  2486
# The Born Machine Outputs Probabilites
#  {'00': 0.5395, '01': 0.116, '10': 0.1255, '11': 0.219}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2486 is 0.07286266964793242
# The Variation Distance for epoch  2486 is 0.14094357041219932
#
# This is Epoch number:  2487
# The Born Machine Outputs Probabilites
#  {'00': 0.5375, '01': 0.1085, '10': 0.138, '11': 0.216}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2487 is 0.07395437386925574
# The Variation Distance for epoch  2487 is 0.14085603155709375
#
# This is Epoch number:  2488
# The Born Machine Outputs Probabilites
#  {'00': 0.5065, '01': 0.1325, '10': 0.144, '11': 0.217}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2488 is 0.0631520427783312
# The Variation Distance for epoch  2488 is 0.14076892984913156
#
# This is Epoch number:  2489
# The Born Machine Outputs Probabilites
#  {'00': 0.521, '01': 0.125, '10': 0.138, '11': 0.216}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2489 is 0.06758738679340504
# The Variation Distance for epoch  2489 is 0.1406825246731882
#
# This is Epoch number:  2490
# The Born Machine Outputs Probabilites
#  {'00': 0.523, '01': 0.125, '10': 0.1335, '11': 0.2185}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2490 is 0.06771072344173978
# The Variation Distance for epoch  2490 is 0.14059648219706966
#
# This is Epoch number:  2491
# The Born Machine Outputs Probabilites
#  {'00': 0.5415, '01': 0.1175, '10': 0.132, '11': 0.209}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2491 is 0.07444398308049016
# The Variation Distance for epoch  2491 is 0.140510290261683
#
# This is Epoch number:  2492
# The Born Machine Outputs Probabilites
#  {'00': 0.536, '01': 0.1265, '10': 0.128, '11': 0.2095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2492 is 0.07172367437157945
# The Variation Distance for epoch  2492 is 0.14042391868608803
#
# This is Epoch number:  2493
# The Born Machine Outputs Probabilites
#  {'00': 0.518, '01': 0.1145, '10': 0.1285, '11': 0.239}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2493 is 0.06564572171645722
# The Variation Distance for epoch  2493 is 0.14033786743799778
#
# This is Epoch number:  2494
# The Born Machine Outputs Probabilites
#  {'00': 0.5125, '01': 0.123, '10': 0.1405, '11': 0.224}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2494 is 0.06496315487210591
# The Variation Distance for epoch  2494 is 0.14025143171341753
#
# This is Epoch number:  2495
# The Born Machine Outputs Probabilites
#  {'00': 0.503, '01': 0.129, '10': 0.1435, '11': 0.2245}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2495 is 0.061951826632885565
# The Variation Distance for epoch  2495 is 0.14016500690111944
#
# This is Epoch number:  2496
# The Born Machine Outputs Probabilites
#  {'00': 0.5195, '01': 0.119, '10': 0.1295, '11': 0.232}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2496 is 0.06612571296708825
# The Variation Distance for epoch  2496 is 0.1400791554202898
#
# This is Epoch number:  2497
# The Born Machine Outputs Probabilites
#  {'00': 0.52, '01': 0.12, '10': 0.1395, '11': 0.2205}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2497 is 0.06753301881656792
# The Variation Distance for epoch  2497 is 0.1399934622515944
#
# This is Epoch number:  2498
# The Born Machine Outputs Probabilites
#  {'00': 0.5185, '01': 0.1265, '10': 0.142, '11': 0.213}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2498 is 0.0672092642175669
# The Variation Distance for epoch  2498 is 0.13990719591722878
# Execution Time is: 1978.9564530849457

# %%
a = loss[('MMD', 'Test')]

# %%
np.savetxt('dat.txt', a)

# %%
a = np.array(a)

# %%
a
# Out:
# array([0.22256605, 0.21922688, 0.22220296, 0.22990413, 0.2080287 ,
#        0.21574356, 0.20853694, 0.22006953, 0.21117269, 0.22326336,
#        0.22408681, 0.21391392, 0.21864101, 0.22276128, 0.22101713,
#        0.22109485, 0.21350083, 0.21813387, 0.21702851, 0.21445939,
#        0.21831915, 0.2222931 , 0.21096557, 0.21159453, 0.21611203,
#        0.23224025, 0.21424457, 0.2105285 , 0.21629383])

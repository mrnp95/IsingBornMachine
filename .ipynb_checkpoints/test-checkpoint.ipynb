# %%
## @package run_and_compare
# This is the main module for this project.
#
# More details.

import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, style
from param_init import NetworkParams
from file_operations_out import PrintFinalParamsToFile, PrintDataToFiles, MakeDirectory, PrintFinalParamsToFile
from file_operations_in import DataImport, DataDictFromFile
from train_plot import CostPlot
from cost_function_train import TrainBorn

from random import shuffle
from auxiliary_functions import TrainTestPartition, num_bytes_needed
from pyquil.api import get_qc
import sys
import os
import time
## This function gathers inputs from file
#
# @param[in] file_name name of file to gather inputs from
# 
# @param[out] N_epochs number of epochs
# @param[out] data_type
# @param[out] N_data_samples
# @param[out] N_born_samples
# @param[out] N_kernel_samples
# @param[out] batch_size
# @param[out] kernel_type
# @param[out] cost_func
# @param[out] device_name
# @param[out] as_qvm_value
#
# @returns listed parameters
def get_inputs(file_name):
    
    with open(file_name, 'r') as input_file:
   
        input_values = input_file.readlines()

        N_epochs = int(input_values[0])
        learning_rate = float(input_values[1])
        data_type = str(input_values[2])
        data_type = data_type[0:len(data_type) - 1]
        N_data_samples = int(input_values[3])
        N_born_samples = int(input_values[4])
        N_kernel_samples = int(input_values[5])
        batch_size = int(input_values[6])
        kernel_type = str(input_values[7])
        kernel_type = kernel_type[0:len(kernel_type) - 1]
        cost_func = str(input_values[8])
        cost_func = cost_func[0:len(cost_func) - 1]
        device_name = str(input_values[9])
        device_name = device_name[0:len(device_name) - 1]

        if int(input_values[10]) == 1:
            as_qvm_value = True
        else:
            as_qvm_value = False

        score = str(input_values[11])
        score = score[0:len(score) - 1]

        stein_eigvecs = int(input_values[12])
        stein_eta = float(input_values[13])

        stein_params = {}
        stein_params[0] = score                 #Choice of method to approximate Stein Score:                   score
        stein_params[1] = stein_eigvecs         #Number of Nystrom Eigenvectors, J for spectral_stein method:   J
        stein_params[2] = stein_eta             #regularization paramter for identity_stein method:             \chi
        stein_params[3] = kernel_type           #Kernel for computing Stein Score, set to be the same as kernel used in Stein Discrpancy                              
   
        '''Number of samples:'''
        N_samples =     [N_data_samples,\
                        N_born_samples,\
                        batch_size,\
                        N_kernel_samples]
        sinkhorn_eps = float(input_values[14])
        run = int(input_values[15])

    return N_epochs, learning_rate, data_type, N_samples, kernel_type, cost_func, device_name, as_qvm_value, stein_params, sinkhorn_eps, run

def SaveAnimation(framespersec, fig, N_epochs, N_qubits, N_born_samples, cost_func, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples):
      
        Writer = animation.writers['ffmpeg']

        writer = Writer(fps=framespersec, metadata=dict(artist='Me'), bitrate=-1)
        
        ani = animation.FuncAnimation(fig, animate, frames=len(born_probs_list), fargs=(N_qubits, N_born_samples, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples), interval = 10)
        
        animations_path = './animations/'
        MakeDirectory(animations_path)
        
        ani.save("animations/%s_%iQbs_%s_Kernel_%iSamples_%iEpochs.mp4" \
                %(cost_func[0:1], N_qubits, kernel_type[0][0], N_born_samples, N_epochs))

        plt.show(block=False)       
        plt.pause(1)
        plt.close()
def PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict):
   
        plt.legend(prop={'size': 7}, loc='best').draggable()
        
        plots_path = './plots/'
        MakeDirectory(plots_path)
        plt.savefig("plots/%s_%iQbs_%s_%iBSamps_%iEpoch.pdf" \
                %(cost_func[0], N_qubits, kernel_type[0][0], N_born_samples, N_epochs))
        
        fig, axs = plt.subplots()
        
        axs.set_xlabel("Outcomes")
        axs.set_ylabel("Probability")
        axs.legend(('Born Probs','Data Probs'))
        axs.set_xticks(range(len(data_exact_dict)))
        axs.set_xticklabels(list(data_exact_dict.keys()),rotation=70)
        axs.set_title("%i Qubits, %s Kernel, %i Born Samples" \
                %(N_qubits, kernel_type[0][0], N_born_samples))
        
        plt.tight_layout()
        
        return fig, axs

def animate(i, N_qubits, N_born_samples, kernel_type,  data_exact_dict, born_probs_list, axs, N_data_samples):
        plot_colour = ['r', 'b']
        axs.clear()
        x = np.arange(len(data_exact_dict))
        axs.bar(x, born_probs_list[i].values(), width=0.2, color= plot_colour[0], align='center')
        axs.bar(x-0.2, data_exact_dict.values(), width=0.2, color='b', align='center')
        axs.set_title("%i Qbs, %s Kernel, %i Data Samps, %i Born Samps" \
                %(N_qubits, kernel_type[0][0], N_data_samples, N_born_samples))
        axs.set_xlabel("Outcomes")
        axs.set_ylabel("Probability")
        axs.legend(('Born Probs','Data Probs'))
        axs.set_xticks(range(len(data_exact_dict)))
        axs.set_xticklabels(list(data_exact_dict.keys()),rotation=70)
      
def bytes_to_int(bytes_list):
    total = 0
    for byte in bytes_list:
        total *= 256
        total += byte

    return total

def read_ints_from_file(N_qubits, N_data_samples, f):
    int_list = [0] * N_data_samples
    bytes_list = list(f.read())
    for sample in range(N_data_samples):
        int_list[sample] = bytes_to_int(bytes_list[sample * num_bytes_needed(N_qubits):(sample + 1) * num_bytes_needed(N_qubits)])

    return int_list


# ## This is the main function
# def main():

#     if len(sys.argv) != 2:
#         sys.exit("[ERROR] : There should be exactly one input. Namely, a txt file containing the input values. Please see the README.md file for more details.")
#     else:
#         N_epochs, learning_rate, data_type, N_samples, kernel_type,cost_func, device_name, as_qvm_value, stein_params, sinkhorn_eps, run = get_inputs(sys.argv[1])
        
#         if type(device_name) is not str:
#                 raise ValueError('The device name must be a string')
#         if (as_qvm_value is not True and as_qvm_value is not False):
#                 raise ValueError('\'as_qvm_value\' must be an integer, either 0, or 1')

#         qc = get_qc(device_name, as_qvm = as_qvm_value)  
#         N_qubits = len(qc.qubits())
#         data_circuit_choice = 'IQP'

#         N_data_samples = N_samples[0]
#         N_born_samples = N_samples[1]

#         if data_type == 'Quantum_Data':

#             try:
#                 data_samples= list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))
#             except:
#                 PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
#                 data_samples = list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))

#         elif data_type == 'Bernoulli_Data':
            
#             try:
#                 with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
#                     data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

#             except:
#                 PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
#                 with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
#                     data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

#             print("read data =")
#             data_samples_orig
#             data_samples = np.zeros((N_data_samples, N_qubits), dtype = int)

#             for sample in range(0, N_data_samples):
            
#                 temp = data_samples_orig[sample]

#                 for outcome in range(0, N_qubits):

#                     data_samples[sample, N_qubits - 1 - outcome] = temp % 2
#                     temp >>= 1

#         else:
#             sys.exit("[ERROR] : data_type should be either 'Quantum_Data' or 'Bernoulli_Data'")
    
#         np.random.shuffle(data_samples)

#         #Split data into training/test sets
#         data_train_test = TrainTestPartition(data_samples)

#         random_seed = 0

#         #Parameters, J, b for epoch 0 at random, gamma = constant = pi/4
#         #Set random seed to 0 to initialise the actual Born machine to be trained
#         initial_params = NetworkParams(qc, random_seed)

#         data_exact_dict = DataDictFromFile(data_type, N_qubits, 'infinite', data_circuit_choice)
#         t0 = time.time()
#         loss, circuit_params, born_probs_list, empirical_probs_list = TrainBorn(qc, cost_func, initial_params, \
#                                                                             N_epochs, N_samples, data_train_test, data_exact_dict, \
#                                                                             kernel_type, 'Precompute', learning_rate, \
#                                                                             stein_params, sinkhorn_eps)


#         t1 = time.time()
#         print('Execution Time is:', t1-t0)                                              
#         plt.figure(1)

#         CostPlot(N_qubits, kernel_type, data_train_test, N_samples, cost_func, loss, circuit_params, born_probs_list, empirical_probs_list)
        

#         fig, axs = PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict)
#         SaveAnimation(5, fig, N_epochs, N_qubits,  N_born_samples, cost_func, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples)
        

#         PrintFinalParamsToFile(cost_func, data_type, data_circuit_choice, N_epochs, \
#                                 learning_rate, loss, circuit_params, data_exact_dict, born_probs_list, empirical_probs_list, \
#                                 qc, kernel_type, N_samples, stein_params, sinkhorn_eps, run)

# if __name__ == "__main__":

#     main()

# %%
if 2 != 2:
    sys.exit("[ERROR] : There should be exactly one input. Namely, a txt file containing the input values. Please see the README.md file for more details.")
else:
    N_epochs, learning_rate, data_type, N_samples, kernel_type,cost_func, device_name, as_qvm_value, stein_params, sinkhorn_eps, run = get_inputs('./inputs.txt')

    if type(device_name) is not str:
            raise ValueError('The device name must be a string')
    if (as_qvm_value is not True and as_qvm_value is not False):
            raise ValueError('\'as_qvm_value\' must be an integer, either 0, or 1')

    qc = get_qc(device_name, as_qvm = as_qvm_value)  
    N_qubits = len(qc.qubits())
    data_circuit_choice = 'IQP'

    N_data_samples = N_samples[0]
    N_born_samples = N_samples[1]

    if data_type == 'Quantum_Data':

        try:
            data_samples= list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))
        except:
            PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
            data_samples = list(np.loadtxt('data/Quantum_Data_%iQBs_%iSamples_%sCircuit' % (N_qubits, N_data_samples, data_circuit_choice), dtype = str))

    elif data_type == 'Bernoulli_Data':

        try:
            with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
                data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

        except:
            PrintDataToFiles(data_type, N_data_samples, qc, data_circuit_choice, N_qubits)
            with open('binary_data/Bernoulli_Data_%iQBs_%iSamples' % (N_qubits, N_data_samples), 'rb') as f:
                data_samples_orig = read_ints_from_file(N_qubits, N_data_samples, f)

        print("read data =")
        data_samples_orig
        data_samples = np.zeros((N_data_samples, N_qubits), dtype = int)

        for sample in range(0, N_data_samples):

            temp = data_samples_orig[sample]

            for outcome in range(0, N_qubits):

                data_samples[sample, N_qubits - 1 - outcome] = temp % 2
                temp >>= 1

    else:
        sys.exit("[ERROR] : data_type should be either 'Quantum_Data' or 'Bernoulli_Data'")

    np.random.shuffle(data_samples)

    #Split data into training/test sets
    data_train_test = TrainTestPartition(data_samples)

    random_seed = 0

    #Parameters, J, b for epoch 0 at random, gamma = constant = pi/4
    #Set random seed to 0 to initialise the actual Born machine to be trained
    initial_params = NetworkParams(qc, random_seed)

    data_exact_dict = DataDictFromFile(data_type, N_qubits, 'infinite', data_circuit_choice)
    t0 = time.time()
    loss, circuit_params, born_probs_list, empirical_probs_list = TrainBorn(qc, cost_func, initial_params, \
                                                                        N_epochs, N_samples, data_train_test, data_exact_dict, \
                                                                        kernel_type, 'Precompute', learning_rate, \
                                                                        stein_params, sinkhorn_eps)


    t1 = time.time()
    print('Execution Time is:', t1-t0)                                              
    plt.figure(1)

#     CostPlot(N_qubits, kernel_type, data_train_test, N_samples, cost_func, loss, circuit_params, born_probs_list, empirical_probs_list)


#     fig, axs = PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict)
#     SaveAnimation(5, fig, N_epochs, N_qubits,  N_born_samples, cost_func, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples)


    PrintFinalParamsToFile(cost_func, data_type, data_circuit_choice, N_epochs, \
                            learning_rate, loss, circuit_params, data_exact_dict, born_probs_list, empirical_probs_list, \
                            qc, kernel_type, N_samples, stein_params, sinkhorn_eps, run)
# Out:
# read data =
# The lattice is: 2q-qvm
#
# This is Epoch number:  0
# The Born Machine Outputs Probabilites
#  {'00': 0.849, '01': 0.02, '10': 0.0245, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  0 is 0.2156217495971262
# The Variation Distance for epoch  0 is 0.49012552413175164
# /Users/reza/projects/PycharmProjects/IsingBornMachine/sample_gen.py:35: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   born_samples = np.flip(np.vstack(born_samples_all_qubits_dict[q] for q in sorted(qc.qubits())).T, 1) #put outcomes into array
# /Users/reza/projects/PycharmProjects/IsingBornMachine/sample_gen.py:58: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   born_samples_pm.append(np.flip(np.vstack(born_samples_plus_all_qbs_dict[q] for q in sorted(qc.qubits())).T, 1))
# /Users/reza/projects/PycharmProjects/IsingBornMachine/sample_gen.py:59: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   born_samples_pm.append(np.flip(np.vstack(born_samples_minus_all_qbs_dict[q] for q in sorted(qc.qubits())).T, 1))
# This is Epoch number:  1
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.0145, '10': 0.037, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  1 is 0.21308494316760218
# The Variation Distance for epoch  1 is 0.48996910793169196
#
# This is Epoch number:  2
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.0145, '10': 0.034, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  2 is 0.21317956089335088
# The Variation Distance for epoch  2 is 0.4898135325909962
#
# This is Epoch number:  3
# The Born Machine Outputs Probabilites
#  {'00': 0.85, '01': 0.0185, '10': 0.027, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  3 is 0.21670317655370108
# The Variation Distance for epoch  3 is 0.4896581390654821
#
# This is Epoch number:  4
# The Born Machine Outputs Probabilites
#  {'00': 0.838, '01': 0.019, '10': 0.0295, '11': 0.1135}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  4 is 0.2091710948812029
# The Variation Distance for epoch  4 is 0.48950352342587417
#
# This is Epoch number:  5
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.016, '10': 0.0365, '11': 0.103}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  5 is 0.2147175509596423
# The Variation Distance for epoch  5 is 0.4893483856854054
#
# This is Epoch number:  6
# The Born Machine Outputs Probabilites
#  {'00': 0.8315, '01': 0.017, '10': 0.0365, '11': 0.115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  6 is 0.20612530920164773
# The Variation Distance for epoch  6 is 0.48919393809138745
#
# This is Epoch number:  7
# The Born Machine Outputs Probabilites
#  {'00': 0.859, '01': 0.0145, '10': 0.0305, '11': 0.096}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  7 is 0.2233464492138385
# The Variation Distance for epoch  7 is 0.4890408380710243
#
# This is Epoch number:  8
# The Born Machine Outputs Probabilites
#  {'00': 0.847, '01': 0.0195, '10': 0.0345, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  8 is 0.21615422452091915
# The Variation Distance for epoch  8 is 0.48888598993735977
#
# This is Epoch number:  9
# The Born Machine Outputs Probabilites
#  {'00': 0.857, '01': 0.0155, '10': 0.033, '11': 0.0945}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  9 is 0.2225091302444422
# The Variation Distance for epoch  9 is 0.48873162148979227
#
# This is Epoch number:  10
# The Born Machine Outputs Probabilites
#  {'00': 0.848, '01': 0.0185, '10': 0.0345, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  10 is 0.2167895538269382
# The Variation Distance for epoch  10 is 0.488575667707725
#
# This is Epoch number:  11
# The Born Machine Outputs Probabilites
#  {'00': 0.848, '01': 0.014, '10': 0.0285, '11': 0.1095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  11 is 0.21547381288773482
# The Variation Distance for epoch  11 is 0.48841895844990324
#
# This is Epoch number:  12
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.0195, '10': 0.033, '11': 0.0955}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  12 is 0.21926058389737024
# The Variation Distance for epoch  12 is 0.4882620573247492
#
# This is Epoch number:  13
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.0135, '10': 0.0385, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  13 is 0.2150168005406552
# The Variation Distance for epoch  13 is 0.4881051631173712
#
# This is Epoch number:  14
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.0175, '10': 0.0345, '11': 0.0965}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  14 is 0.21912707813142152
# The Variation Distance for epoch  14 is 0.4879482625751142
#
# This is Epoch number:  15
# The Born Machine Outputs Probabilites
#  {'00': 0.847, '01': 0.016, '10': 0.0345, '11': 0.1025}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  15 is 0.21601315878257776
# The Variation Distance for epoch  15 is 0.4877919930181861
#
# This is Epoch number:  16
# The Born Machine Outputs Probabilites
#  {'00': 0.837, '01': 0.017, '10': 0.0385, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  16 is 0.21012852033207274
# The Variation Distance for epoch  16 is 0.48763531215545947
#
# This is Epoch number:  17
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.0205, '10': 0.0355, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  17 is 0.2150396471007323
# The Variation Distance for epoch  17 is 0.48747910818223994
#
# This is Epoch number:  18
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.0185, '10': 0.029, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  18 is 0.21809862180818596
# The Variation Distance for epoch  18 is 0.4873229536523914
#
# This is Epoch number:  19
# The Born Machine Outputs Probabilites
#  {'00': 0.844, '01': 0.0165, '10': 0.0295, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  19 is 0.21306946598761445
# The Variation Distance for epoch  19 is 0.487166066342675
#
# This is Epoch number:  20
# The Born Machine Outputs Probabilites
#  {'00': 0.851, '01': 0.017, '10': 0.031, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  20 is 0.2180821249983249
# The Variation Distance for epoch  20 is 0.4870104972504082
#
# This is Epoch number:  21
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.0165, '10': 0.035, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  21 is 0.21646744985783772
# The Variation Distance for epoch  21 is 0.48685387673892266
#
# This is Epoch number:  22
# The Born Machine Outputs Probabilites
#  {'00': 0.8455, '01': 0.015, '10': 0.0315, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  22 is 0.21439505191086572
# The Variation Distance for epoch  22 is 0.4866972236490514
#
# This is Epoch number:  23
# The Born Machine Outputs Probabilites
#  {'00': 0.854, '01': 0.015, '10': 0.028, '11': 0.103}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  23 is 0.21946466678100873
# The Variation Distance for epoch  23 is 0.4865400691160919
#
# This is Epoch number:  24
# The Born Machine Outputs Probabilites
#  {'00': 0.8555, '01': 0.0175, '10': 0.0315, '11': 0.0955}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  24 is 0.221270740306714
# The Variation Distance for epoch  24 is 0.48638212657637764
#
# This is Epoch number:  25
# The Born Machine Outputs Probabilites
#  {'00': 0.846, '01': 0.0195, '10': 0.035, '11': 0.0995}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  25 is 0.21557536961139623
# The Variation Distance for epoch  25 is 0.48622395347114317
#
# This is Epoch number:  26
# The Born Machine Outputs Probabilites
#  {'00': 0.844, '01': 0.0175, '10': 0.0395, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  26 is 0.21502845380454194
# The Variation Distance for epoch  26 is 0.4860647430537553
#
# This is Epoch number:  27
# The Born Machine Outputs Probabilites
#  {'00': 0.8395, '01': 0.017, '10': 0.0345, '11': 0.109}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  27 is 0.21102715466637945
# The Variation Distance for epoch  27 is 0.48590537796614053
#
# This is Epoch number:  28
# The Born Machine Outputs Probabilites
#  {'00': 0.8535, '01': 0.017, '10': 0.036, '11': 0.0935}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  28 is 0.22077201679364322
# The Variation Distance for epoch  28 is 0.4857450978139122
#
# This is Epoch number:  29
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.014, '10': 0.029, '11': 0.1125}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  29 is 0.2132284718117532
# The Variation Distance for epoch  29 is 0.4855848606561689
#
# This is Epoch number:  30
# The Born Machine Outputs Probabilites
#  {'00': 0.848, '01': 0.0165, '10': 0.0365, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  30 is 0.21710015324366594
# The Variation Distance for epoch  30 is 0.4854261263813791
#
# This is Epoch number:  31
# The Born Machine Outputs Probabilites
#  {'00': 0.853, '01': 0.0185, '10': 0.038, '11': 0.0905}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  31 is 0.22090223309033974
# The Variation Distance for epoch  31 is 0.48526872703556057
#
# This is Epoch number:  32
# The Born Machine Outputs Probabilites
#  {'00': 0.8375, '01': 0.0185, '10': 0.0355, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  32 is 0.20993994576267638
# The Variation Distance for epoch  32 is 0.48511153735960183
#
# This is Epoch number:  33
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.017, '10': 0.0365, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  33 is 0.20908521026559523
# The Variation Distance for epoch  33 is 0.48495359177547676
#
# This is Epoch number:  34
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.023, '10': 0.045, '11': 0.098}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  34 is 0.20963698577685097
# The Variation Distance for epoch  34 is 0.4847972364605372
#
# This is Epoch number:  35
# The Born Machine Outputs Probabilites
#  {'00': 0.8415, '01': 0.016, '10': 0.0345, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  35 is 0.21232436406138755
# The Variation Distance for epoch  35 is 0.4846392526923646
#
# This is Epoch number:  36
# The Born Machine Outputs Probabilites
#  {'00': 0.851, '01': 0.0195, '10': 0.0325, '11': 0.097}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  36 is 0.21847987625252308
# The Variation Distance for epoch  36 is 0.48448170146943575
#
# This is Epoch number:  37
# The Born Machine Outputs Probabilites
#  {'00': 0.8595, '01': 0.0155, '10': 0.031, '11': 0.094}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  37 is 0.223833528662993
# The Variation Distance for epoch  37 is 0.48432259183284115
#
# This is Epoch number:  38
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.016, '10': 0.031, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  38 is 0.21872081368205698
# The Variation Distance for epoch  38 is 0.48416471882041523
#
# This is Epoch number:  39
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.018, '10': 0.037, '11': 0.0975}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  39 is 0.21692194291509648
# The Variation Distance for epoch  39 is 0.48400709605169806
#
# This is Epoch number:  40
# The Born Machine Outputs Probabilites
#  {'00': 0.8365, '01': 0.0175, '10': 0.0365, '11': 0.1095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  40 is 0.2094324597289835
# The Variation Distance for epoch  40 is 0.48385001994447113
#
# This is Epoch number:  41
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.0135, '10': 0.034, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  41 is 0.21616182157021746
# The Variation Distance for epoch  41 is 0.48369420161842025
#
# This is Epoch number:  42
# The Born Machine Outputs Probabilites
#  {'00': 0.8435, '01': 0.0155, '10': 0.0355, '11': 0.1055}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  42 is 0.2138347131082432
# The Variation Distance for epoch  42 is 0.4835369646981023
#
# This is Epoch number:  43
# The Born Machine Outputs Probabilites
#  {'00': 0.846, '01': 0.0165, '10': 0.0325, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  43 is 0.21497382665448939
# The Variation Distance for epoch  43 is 0.4833802498938687
#
# This is Epoch number:  44
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.0195, '10': 0.0305, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  44 is 0.21403595776816964
# The Variation Distance for epoch  44 is 0.4832233476572145
#
# This is Epoch number:  45
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.0175, '10': 0.0395, '11': 0.0915}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  45 is 0.2201313830592656
# The Variation Distance for epoch  45 is 0.48306688922215446
#
# This is Epoch number:  46
# The Born Machine Outputs Probabilites
#  {'00': 0.8465, '01': 0.0215, '10': 0.0315, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  46 is 0.2153192365475507
# The Variation Distance for epoch  46 is 0.4829103740545432
#
# This is Epoch number:  47
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.0185, '10': 0.031, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  47 is 0.21848428368805628
# The Variation Distance for epoch  47 is 0.48275229212782556
#
# This is Epoch number:  48
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.0155, '10': 0.034, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  48 is 0.21321339002926087
# The Variation Distance for epoch  48 is 0.4825946156522112
#
# This is Epoch number:  49
# The Born Machine Outputs Probabilites
#  {'00': 0.8295, '01': 0.02, '10': 0.0395, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  49 is 0.20547063329240256
# The Variation Distance for epoch  49 is 0.4824366810709043
#
# This is Epoch number:  50
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.019, '10': 0.043, '11': 0.104}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  50 is 0.20908115852998344
# The Variation Distance for epoch  50 is 0.48227937736731297
#
# This is Epoch number:  51
# The Born Machine Outputs Probabilites
#  {'00': 0.855, '01': 0.018, '10': 0.038, '11': 0.089}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  51 is 0.22225605358957923
# The Variation Distance for epoch  51 is 0.4821229250155728
#
# This is Epoch number:  52
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.018, '10': 0.0345, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  52 is 0.21339912020821494
# The Variation Distance for epoch  52 is 0.4819663588786437
#
# This is Epoch number:  53
# The Born Machine Outputs Probabilites
#  {'00': 0.8375, '01': 0.0145, '10': 0.0405, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  53 is 0.21076272414599562
# The Variation Distance for epoch  53 is 0.48180942789082365
#
# This is Epoch number:  54
# The Born Machine Outputs Probabilites
#  {'00': 0.8565, '01': 0.018, '10': 0.028, '11': 0.0975}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  54 is 0.2212945121959935
# The Variation Distance for epoch  54 is 0.48165077389504796
#
# This is Epoch number:  55
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.015, '10': 0.0335, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  55 is 0.21443933883415855
# The Variation Distance for epoch  55 is 0.48149147020131244
#
# This is Epoch number:  56
# The Born Machine Outputs Probabilites
#  {'00': 0.8405, '01': 0.02, '10': 0.0385, '11': 0.101}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  56 is 0.21257648878732027
# The Variation Distance for epoch  56 is 0.4813337138547934
#
# This is Epoch number:  57
# The Born Machine Outputs Probabilites
#  {'00': 0.8315, '01': 0.0195, '10': 0.0425, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  57 is 0.20734546647421614
# The Variation Distance for epoch  57 is 0.481176718640589
#
# This is Epoch number:  58
# The Born Machine Outputs Probabilites
#  {'00': 0.829, '01': 0.02, '10': 0.0425, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  58 is 0.20571528619174528
# The Variation Distance for epoch  58 is 0.4810194730281964
#
# This is Epoch number:  59
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.0185, '10': 0.0365, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  59 is 0.20814382675052856
# The Variation Distance for epoch  59 is 0.48086306480230273
#
# This is Epoch number:  60
# The Born Machine Outputs Probabilites
#  {'00': 0.8445, '01': 0.016, '10': 0.043, '11': 0.0965}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  60 is 0.21600735965658824
# The Variation Distance for epoch  60 is 0.4807066194199821
#
# This is Epoch number:  61
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.0185, '10': 0.032, '11': 0.098}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  61 is 0.21867894249832576
# The Variation Distance for epoch  61 is 0.4805511919224952
#
# This is Epoch number:  62
# The Born Machine Outputs Probabilites
#  {'00': 0.8455, '01': 0.016, '10': 0.0395, '11': 0.099}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  62 is 0.21598181035236652
# The Variation Distance for epoch  62 is 0.48039465957040034
#
# This is Epoch number:  63
# The Born Machine Outputs Probabilites
#  {'00': 0.8515, '01': 0.018, '10': 0.033, '11': 0.0975}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  63 is 0.21885312123770906
# The Variation Distance for epoch  63 is 0.48023892840019033
#
# This is Epoch number:  64
# The Born Machine Outputs Probabilites
#  {'00': 0.8485, '01': 0.016, '10': 0.035, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  64 is 0.21712434536328595
# The Variation Distance for epoch  64 is 0.4800816087973612
#
# This is Epoch number:  65
# The Born Machine Outputs Probabilites
#  {'00': 0.831, '01': 0.0195, '10': 0.036, '11': 0.1135}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  65 is 0.205781161434062
# The Variation Distance for epoch  65 is 0.4799241921402999
#
# This is Epoch number:  66
# The Born Machine Outputs Probabilites
#  {'00': 0.8375, '01': 0.0225, '10': 0.0335, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  66 is 0.209708753323263
# The Variation Distance for epoch  66 is 0.4797679286829679
#
# This is Epoch number:  67
# The Born Machine Outputs Probabilites
#  {'00': 0.852, '01': 0.0185, '10': 0.034, '11': 0.0955}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  67 is 0.21941336863069982
# The Variation Distance for epoch  67 is 0.4796111175238779
#
# This is Epoch number:  68
# The Born Machine Outputs Probabilites
#  {'00': 0.848, '01': 0.0195, '10': 0.0385, '11': 0.094}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  68 is 0.2176270471222943
# The Variation Distance for epoch  68 is 0.47945334382435995
#
# This is Epoch number:  69
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.015, '10': 0.0375, '11': 0.1}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  69 is 0.21689929180183798
# The Variation Distance for epoch  69 is 0.4792958126503409
#
# This is Epoch number:  70
# The Born Machine Outputs Probabilites
#  {'00': 0.837, '01': 0.018, '10': 0.0285, '11': 0.1165}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  70 is 0.2082990667997684
# The Variation Distance for epoch  70 is 0.47913759660558597
#
# This is Epoch number:  71
# The Born Machine Outputs Probabilites
#  {'00': 0.846, '01': 0.0125, '10': 0.034, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  71 is 0.21512008328501964
# The Variation Distance for epoch  71 is 0.478979407682722
#
# This is Epoch number:  72
# The Born Machine Outputs Probabilites
#  {'00': 0.839, '01': 0.0185, '10': 0.0325, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  72 is 0.21037064937046912
# The Variation Distance for epoch  72 is 0.47882162413970325
#
# This is Epoch number:  73
# The Born Machine Outputs Probabilites
#  {'00': 0.8385, '01': 0.015, '10': 0.0365, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  73 is 0.21067604618749336
# The Variation Distance for epoch  73 is 0.47866293149729733
#
# This is Epoch number:  74
# The Born Machine Outputs Probabilites
#  {'00': 0.8375, '01': 0.0235, '10': 0.037, '11': 0.102}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  74 is 0.2104189693189924
# The Variation Distance for epoch  74 is 0.4785021805049555
#
# This is Epoch number:  75
# The Born Machine Outputs Probabilites
#  {'00': 0.846, '01': 0.018, '10': 0.0415, '11': 0.0945}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  75 is 0.21680522157926618
# The Variation Distance for epoch  75 is 0.4783422861714793
#
# This is Epoch number:  76
# The Born Machine Outputs Probabilites
#  {'00': 0.843, '01': 0.0195, '10': 0.0305, '11': 0.107}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  76 is 0.21269601499814583
# The Variation Distance for epoch  76 is 0.47818343506273064
#
# This is Epoch number:  77
# The Born Machine Outputs Probabilites
#  {'00': 0.849, '01': 0.018, '10': 0.03, '11': 0.103}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  77 is 0.21657610405550531
# The Variation Distance for epoch  77 is 0.478025061408627
#
# This is Epoch number:  78
# The Born Machine Outputs Probabilites
#  {'00': 0.838, '01': 0.0235, '10': 0.035, '11': 0.1035}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  78 is 0.21036735268135887
# The Variation Distance for epoch  78 is 0.47786619784346035
#
# This is Epoch number:  79
# The Born Machine Outputs Probabilites
#  {'00': 0.8365, '01': 0.021, '10': 0.036, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  79 is 0.2094615565662713
# The Variation Distance for epoch  79 is 0.47770774689997403
#
# This is Epoch number:  80
# The Born Machine Outputs Probabilites
#  {'00': 0.8425, '01': 0.016, '10': 0.037, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  80 is 0.21347212211571343
# The Variation Distance for epoch  80 is 0.47755072522546443
#
# This is Epoch number:  81
# The Born Machine Outputs Probabilites
#  {'00': 0.853, '01': 0.0175, '10': 0.035, '11': 0.0945}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  81 is 0.22025157388139416
# The Variation Distance for epoch  81 is 0.47739376079625234
#
# This is Epoch number:  82
# The Born Machine Outputs Probabilites
#  {'00': 0.851, '01': 0.017, '10': 0.0395, '11': 0.0925}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  82 is 0.21976613802889444
# The Variation Distance for epoch  82 is 0.477236491244973
#
# This is Epoch number:  83
# The Born Machine Outputs Probabilites
#  {'00': 0.8255, '01': 0.0195, '10': 0.0365, '11': 0.1185}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  83 is 0.20229020571603973
# The Variation Distance for epoch  83 is 0.4770783403166701
#
# This is Epoch number:  84
# The Born Machine Outputs Probabilites
#  {'00': 0.8385, '01': 0.026, '10': 0.0395, '11': 0.096}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  84 is 0.2116910373873807
# The Variation Distance for epoch  84 is 0.4769202998797559
#
# This is Epoch number:  85
# The Born Machine Outputs Probabilites
#  {'00': 0.8485, '01': 0.016, '10': 0.036, '11': 0.0995}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  85 is 0.2173204727617426
# The Variation Distance for epoch  85 is 0.47676142459102683
#
# This is Epoch number:  86
# The Born Machine Outputs Probabilites
#  {'00': 0.8415, '01': 0.022, '10': 0.036, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  86 is 0.21284230711966945
# The Variation Distance for epoch  86 is 0.4766041815836886
#
# This is Epoch number:  87
# The Born Machine Outputs Probabilites
#  {'00': 0.847, '01': 0.017, '10': 0.038, '11': 0.098}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  87 is 0.21673956231484615
# The Variation Distance for epoch  87 is 0.47644553644034593
#
# This is Epoch number:  88
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.0155, '10': 0.0395, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  88 is 0.20828641685291593
# The Variation Distance for epoch  88 is 0.4762849727021912
#
# This is Epoch number:  89
# The Born Machine Outputs Probabilites
#  {'00': 0.8425, '01': 0.018, '10': 0.035, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  89 is 0.2131600855703949
# The Variation Distance for epoch  89 is 0.47612608922672917
#
# This is Epoch number:  90
# The Born Machine Outputs Probabilites
#  {'00': 0.8405, '01': 0.022, '10': 0.0395, '11': 0.098}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  90 is 0.21285732135412527
# The Variation Distance for epoch  90 is 0.4759677829602344
#
# This is Epoch number:  91
# The Born Machine Outputs Probabilites
#  {'00': 0.8345, '01': 0.02, '10': 0.037, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  91 is 0.20828984766193048
# The Variation Distance for epoch  91 is 0.4758111106931056
#
# This is Epoch number:  92
# The Born Machine Outputs Probabilites
#  {'00': 0.84, '01': 0.018, '10': 0.034, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  92 is 0.21129984708113525
# The Variation Distance for epoch  92 is 0.47565335603475223
#
# This is Epoch number:  93
# The Born Machine Outputs Probabilites
#  {'00': 0.832, '01': 0.021, '10': 0.036, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  93 is 0.2064871045753396
# The Variation Distance for epoch  93 is 0.47549681832523494
#
# This is Epoch number:  94
# The Born Machine Outputs Probabilites
#  {'00': 0.8475, '01': 0.0155, '10': 0.0365, '11': 0.1005}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  94 is 0.21672186379332725
# The Variation Distance for epoch  94 is 0.47533922808208734
#
# This is Epoch number:  95
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.0145, '10': 0.033, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  95 is 0.21232455350147073
# The Variation Distance for epoch  95 is 0.47518015275598907
#
# This is Epoch number:  96
# The Born Machine Outputs Probabilites
#  {'00': 0.8215, '01': 0.0225, '10': 0.0385, '11': 0.1175}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  96 is 0.20015657060441017
# The Variation Distance for epoch  96 is 0.4750195949683018
#
# This is Epoch number:  97
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.022, '10': 0.028, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  97 is 0.21165701593712927
# The Variation Distance for epoch  97 is 0.47486057101833323
#
# This is Epoch number:  98
# The Born Machine Outputs Probabilites
#  {'00': 0.8565, '01': 0.018, '10': 0.0305, '11': 0.095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  98 is 0.22178266174169736
# The Variation Distance for epoch  98 is 0.47470018840572314
#
# This is Epoch number:  99
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.0155, '10': 0.0415, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  99 is 0.20800960758668752
# The Variation Distance for epoch  99 is 0.4745396457563571
#
# This is Epoch number:  100
# The Born Machine Outputs Probabilites
#  {'00': 0.837, '01': 0.0145, '10': 0.042, '11': 0.1065}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  100 is 0.21072197343391996
# The Variation Distance for epoch  100 is 0.47438027860040927
#
# This is Epoch number:  101
# The Born Machine Outputs Probabilites
#  {'00': 0.8545, '01': 0.019, '10': 0.0335, '11': 0.093}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  101 is 0.2210494497110037
# The Variation Distance for epoch  101 is 0.47421995346204293
#
# This is Epoch number:  102
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.0195, '10': 0.029, '11': 0.1185}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  102 is 0.20581292955647712
# The Variation Distance for epoch  102 is 0.47405903259886917
#
# This is Epoch number:  103
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.0165, '10': 0.0355, '11': 0.112}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  103 is 0.20888111475223214
# The Variation Distance for epoch  103 is 0.47389982104669776
#
# This is Epoch number:  104
# The Born Machine Outputs Probabilites
#  {'00': 0.83, '01': 0.019, '10': 0.034, '11': 0.117}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  104 is 0.2047438563491455
# The Variation Distance for epoch  104 is 0.47374057534386477
#
# This is Epoch number:  105
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.02, '10': 0.034, '11': 0.104}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  105 is 0.2127100111218082
# The Variation Distance for epoch  105 is 0.47358189606754414
#
# This is Epoch number:  106
# The Born Machine Outputs Probabilites
#  {'00': 0.8465, '01': 0.0175, '10': 0.036, '11': 0.1}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  106 is 0.2160268108216844
# The Variation Distance for epoch  106 is 0.4734234605818256
#
# This is Epoch number:  107
# The Born Machine Outputs Probabilites
#  {'00': 0.846, '01': 0.021, '10': 0.0355, '11': 0.0975}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  107 is 0.2157379564088885
# The Variation Distance for epoch  107 is 0.47326459672868937
#
# This is Epoch number:  108
# The Born Machine Outputs Probabilites
#  {'00': 0.8455, '01': 0.021, '10': 0.0275, '11': 0.106}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  108 is 0.21386659818038067
# The Variation Distance for epoch  108 is 0.47310536924014857
#
# This is Epoch number:  109
# The Born Machine Outputs Probabilites
#  {'00': 0.845, '01': 0.018, '10': 0.031, '11': 0.106}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  109 is 0.2140732410408922
# The Variation Distance for epoch  109 is 0.4729447118523303
#
# This is Epoch number:  110
# The Born Machine Outputs Probabilites
#  {'00': 0.8315, '01': 0.018, '10': 0.0415, '11': 0.109}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  110 is 0.20710105567887982
# The Variation Distance for epoch  110 is 0.4727834589929154
#
# This is Epoch number:  111
# The Born Machine Outputs Probabilites
#  {'00': 0.8405, '01': 0.017, '10': 0.0315, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  111 is 0.21112895803508314
# The Variation Distance for epoch  111 is 0.4726218466005512
#
# This is Epoch number:  112
# The Born Machine Outputs Probabilites
#  {'00': 0.8245, '01': 0.0245, '10': 0.0455, '11': 0.1055}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  112 is 0.20350331501538033
# The Variation Distance for epoch  112 is 0.4724617735997085
#
# This is Epoch number:  113
# The Born Machine Outputs Probabilites
#  {'00': 0.8415, '01': 0.014, '10': 0.035, '11': 0.1095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  113 is 0.21235295320720948
# The Variation Distance for epoch  113 is 0.4723025102823414
#
# This is Epoch number:  114
# The Born Machine Outputs Probabilites
#  {'00': 0.8425, '01': 0.016, '10': 0.0335, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  114 is 0.2128018323290165
# The Variation Distance for epoch  114 is 0.47214407450360046
#
# This is Epoch number:  115
# The Born Machine Outputs Probabilites
#  {'00': 0.8455, '01': 0.0165, '10': 0.0335, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  115 is 0.21482911801959026
# The Variation Distance for epoch  115 is 0.47198639034787016
#
# This is Epoch number:  116
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.018, '10': 0.0335, '11': 0.1155}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  116 is 0.20658350815277204
# The Variation Distance for epoch  116 is 0.47182836927230387
#
# This is Epoch number:  117
# The Born Machine Outputs Probabilites
#  {'00': 0.831, '01': 0.022, '10': 0.0425, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  117 is 0.20710648943078147
# The Variation Distance for epoch  117 is 0.47166812420998366
#
# This is Epoch number:  118
# The Born Machine Outputs Probabilites
#  {'00': 0.838, '01': 0.0195, '10': 0.034, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  118 is 0.21002361032524297
# The Variation Distance for epoch  118 is 0.4715067817137711
#
# This is Epoch number:  119
# The Born Machine Outputs Probabilites
#  {'00': 0.848, '01': 0.0205, '10': 0.034, '11': 0.0975}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  119 is 0.21677761749829572
# The Variation Distance for epoch  119 is 0.47134533191192624
#
# This is Epoch number:  120
# The Born Machine Outputs Probabilites
#  {'00': 0.835, '01': 0.0205, '10': 0.0395, '11': 0.105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  120 is 0.20911876058687362
# The Variation Distance for epoch  120 is 0.4711829760236487
#
# This is Epoch number:  121
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.0225, '10': 0.031, '11': 0.1135}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  121 is 0.2062703693688006
# The Variation Distance for epoch  121 is 0.47102129700831075
#
# This is Epoch number:  122
# The Born Machine Outputs Probabilites
#  {'00': 0.8505, '01': 0.02, '10': 0.0325, '11': 0.097}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  122 is 0.21816144998687426
# The Variation Distance for epoch  122 is 0.4708598569876664
#
# This is Epoch number:  123
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.0195, '10': 0.0385, '11': 0.106}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  123 is 0.20955289941596877
# The Variation Distance for epoch  123 is 0.47069820110587113
#
# This is Epoch number:  124
# The Born Machine Outputs Probabilites
#  {'00': 0.829, '01': 0.0225, '10': 0.039, '11': 0.1095}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  124 is 0.20513320428024284
# The Variation Distance for epoch  124 is 0.4705366035740644
#
# This is Epoch number:  125
# The Born Machine Outputs Probabilites
#  {'00': 0.8355, '01': 0.018, '10': 0.036, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  125 is 0.20869328162026135
# The Variation Distance for epoch  125 is 0.47037358191778866
#
# This is Epoch number:  126
# The Born Machine Outputs Probabilites
#  {'00': 0.836, '01': 0.0225, '10': 0.037, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  126 is 0.2093782757518391
# The Variation Distance for epoch  126 is 0.47021241777522643
#
# This is Epoch number:  127
# The Born Machine Outputs Probabilites
#  {'00': 0.835, '01': 0.018, '10': 0.034, '11': 0.113}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  127 is 0.20798951119232845
# The Variation Distance for epoch  127 is 0.4700510041617904
#
# This is Epoch number:  128
# The Born Machine Outputs Probabilites
#  {'00': 0.828, '01': 0.023, '10': 0.0345, '11': 0.1145}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  128 is 0.2036558515206479
# The Variation Distance for epoch  128 is 0.4698889655768658
#
# This is Epoch number:  129
# The Born Machine Outputs Probabilites
#  {'00': 0.832, '01': 0.0255, '10': 0.035, '11': 0.1075}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  129 is 0.206464485449543
# The Variation Distance for epoch  129 is 0.46972863155241884
#
# This is Epoch number:  130
# The Born Machine Outputs Probabilites
#  {'00': 0.8365, '01': 0.02, '10': 0.035, '11': 0.1085}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  130 is 0.20923519118457956
# The Variation Distance for epoch  130 is 0.4695685516529086
#
# This is Epoch number:  131
# The Born Machine Outputs Probabilites
#  {'00': 0.84, '01': 0.0235, '10': 0.032, '11': 0.1045}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  131 is 0.21113114207563033
# The Variation Distance for epoch  131 is 0.46940887174059004
#
# This is Epoch number:  132
# The Born Machine Outputs Probabilites
#  {'00': 0.842, '01': 0.0185, '10': 0.0305, '11': 0.109}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  132 is 0.21199196446926072
# The Variation Distance for epoch  132 is 0.4692483749271046
#
# This is Epoch number:  133
# The Born Machine Outputs Probabilites
#  {'00': 0.8385, '01': 0.016, '10': 0.0335, '11': 0.112}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  133 is 0.21014350371783397
# The Variation Distance for epoch  133 is 0.4690877520289638
#
# This is Epoch number:  134
# The Born Machine Outputs Probabilites
#  {'00': 0.83, '01': 0.0265, '10': 0.033, '11': 0.1105}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  134 is 0.2048126978593402
# The Variation Distance for epoch  134 is 0.4689272775438675
#
# This is Epoch number:  135
# The Born Machine Outputs Probabilites
#  {'00': 0.8185, '01': 0.0225, '10': 0.0435, '11': 0.1155}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  135 is 0.19914903090791136
# The Variation Distance for epoch  135 is 0.4687660188450091
#
# This is Epoch number:  136
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.019, '10': 0.037, '11': 0.11}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  136 is 0.20792500728023477
# The Variation Distance for epoch  136 is 0.46860583412541473
#
# This is Epoch number:  137
# The Born Machine Outputs Probabilites
#  {'00': 0.8415, '01': 0.0195, '10': 0.041, '11': 0.098}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  137 is 0.2137229279496764
# The Variation Distance for epoch  137 is 0.4684441348816552
#
# This is Epoch number:  138
# The Born Machine Outputs Probabilites
#  {'00': 0.835, '01': 0.019, '10': 0.0345, '11': 0.1115}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  138 is 0.20811505864614044
# The Variation Distance for epoch  138 is 0.468282801277154
#
# This is Epoch number:  139
# The Born Machine Outputs Probabilites
#  {'00': 0.8285, '01': 0.0205, '10': 0.0365, '11': 0.1145}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  139 is 0.20427051336481283
# The Variation Distance for epoch  139 is 0.46812034838734795
#
# This is Epoch number:  140
# The Born Machine Outputs Probabilites
#  {'00': 0.829, '01': 0.0215, '10': 0.034, '11': 0.1155}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  140 is 0.20416798459067642
# The Variation Distance for epoch  140 is 0.4679578655858326
#
# This is Epoch number:  141
# The Born Machine Outputs Probabilites
#  {'00': 0.8335, '01': 0.021, '10': 0.0395, '11': 0.106}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  141 is 0.20814242290006002
# The Variation Distance for epoch  141 is 0.46779458875837493
#
# This is Epoch number:  142
# The Born Machine Outputs Probabilites
#  {'00': 0.833, '01': 0.0215, '10': 0.0345, '11': 0.111}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  142 is 0.20688205611559263
# The Variation Distance for epoch  142 is 0.467631409745672
#
# This is Epoch number:  143
# The Born Machine Outputs Probabilites
#  {'00': 0.8305, '01': 0.0255, '10': 0.036, '11': 0.108}
# The Data is
# , {'00': 0.15, '01': 0.35000000000000003, '10': 0.15, '11': 0.35000000000000003}
# The MMD Loss for epoch  143 is 0.20566363946112332
# The Variation Distance for epoch  143 is 0.46746822042682196
#
# This is Epoch number:  144
# The Born Machine Outputs Probabilites
#  {'00': 0.834, '01': 0.021, '10': 0.043, '11': 0.102}
# The Data is
# ...
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2706                 artists.remove(spine)
#    2707
# -> 2708         self._update_title_position(renderer)
#    2709
#    2710         if not self.axison or inframe:
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2647                 if bb is not None:
#    2648                     top = max(top, bb.ymax)
# -> 2649             if title.get_window_extent(renderer).ymin < top:
#    2650                 _, y = self.transAxes.inverted().transform((0, top))
#    2651                 title.set_position((x, y))
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     283
#     284         # Full vertical extent of font, including ascenders and descenders:
# --> 285         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     286             "lp", self._fontproperties,
#     287             ismath="TeX" if self.get_usetex() else False)
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     225             texmanager = self.get_texmanager()
#     226             fontsize = prop.get_size_in_points()
# --> 227             w, h, d = texmanager.get_text_width_height_descent(
#     228                 s, fontsize, renderer=self)
#     229             return w, h, d
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
# --> 309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     311                      texfile], tex)
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
# --> 279             raise RuntimeError(
#     280                 'Failed to process string with tex because {} could not be '
#     281                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found
# WARNING - No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-e0139862ac6d> in <module>
#      77
#      78
# ---> 79     fig, axs = PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict)
#      80     SaveAnimation(5, fig, N_epochs, N_qubits,  N_born_samples, cost_func, kernel_type, data_exact_dict, born_probs_list, axs, N_data_samples)
#      81
#
# <ipython-input-28-ff9fef8c62c6> in PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict)
#     103 def PlotAnimate(N_qubits, N_epochs, N_born_samples, cost_func, kernel_type, data_exact_dict):
#     104
# --> 105         plt.legend(prop={'size': 7}, loc='best').draggable()
#     106
#     107         plots_path = './plots/'
#
# AttributeError: 'Legend' object has no attribute 'draggable'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# ~/anaconda3/envs/born/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#
# ~/anaconda3/envs/born/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488
# --> 489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
#
# ~/anaconda3/envs/born/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ~/anaconda3/envs/born/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1701                         err_msg = os.strerror(errno_num)
# -> 1702                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1703                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/envs/born/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746             renderer.stop_rasterizing()
#    2747
# -> 2748         mimage._draw_list_compositing_images(renderer, self, artists)
#    2749
#    2750         renderer.close_group('axes')
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1163
#    1164         ticks_to_draw = self._update_ticks()
# -> 1165         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1166                                                                 renderer)
#    1167
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     283
#     284         # Full vertical extent of font, including ascenders and descenders:
# --> 285         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     286             "lp", self._fontproperties,
#     287             ismath="TeX" if self.get_usetex() else False)
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     225             texmanager = self.get_texmanager()
#     226             fontsize = prop.get_size_in_points()
# --> 227             w, h, d = texmanager.get_text_width_height_descent(
#     228                 s, fontsize, renderer=self)
#     229             return w, h, d
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
# --> 309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     311                      texfile], tex)
#
# ~/anaconda3/envs/born/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
# --> 279             raise RuntimeError(
#     280                 'Failed to process string with tex because {} could not be '
#     281                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found

# %%
a = loss[('MMD', 'Test')]

# %%
a
# Out:
# [0.21703876397260258,
#  0.21368252978942115,
#  0.2166914139453251,
#  0.2242650892324496,
#  0.2030881830590895,
#  0.2105392087908614,
#  0.20361889075608597,
#  0.2145855970270214,
#  0.2062056852585451,
#  0.21786750793530552,
#  0.2184165220155554,
#  0.20892920362305656,
#  0.21338547147893927,
#  0.2172683568242505,
#  0.21574882111003957,
#  0.21558939699270774,
#  0.20835710866651813,
#  0.21292998997929669,
#  0.211789825480575,
#  0.2094439266035305,
#  0.2128978575787408,
#  0.2167552869628493,
#  0.20578748083856702,
#  0.20657321149498908,
#  0.2106743291839095,
#  0.22647028607368924,
#  0.2090640258058345,
#  0.205408100795898,
#  0.21112472091581147]

# %%
a = np.array(a)

# %%
a
# Out:
# array([0.22256605, 0.21922688, 0.22220296, 0.22990413, 0.2080287 ,
#        0.21574356, 0.20853694, 0.22006953, 0.21117269, 0.22326336,
#        0.22408681, 0.21391392, 0.21864101, 0.22276128, 0.22101713,
#        0.22109485, 0.21350083, 0.21813387, 0.21702851, 0.21445939,
#        0.21831915, 0.2222931 , 0.21096557, 0.21159453, 0.21611203,
#        0.23224025, 0.21424457, 0.2105285 , 0.21629383])
